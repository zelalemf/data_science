# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %%
# %%bash
# #pip install ipyparall
# #ls -al /home/jovyan/.jupyter/jupyter_notebook_config.json
# #jupyter --config-dir
# #vi /home/jovyan/.jupyter/jupyter_notebook_config.jhttps://github.com/ipython/ipyparallel.git
# #pip install notebook  ipyparallel
# #wget https://github.com/ipython/ipyparallel.git
# #git clone /home/jovyan/datacourse/data-wrangling/miniprojects/ipyparallel.git
# #pip install /home/jovyan/datacourse/data-wrangling/miniprojects/ipyparallel.git
# #export PIP_REQUIRE_VIRTUALENV=false
# #pip install ipyparallel
# #pip install ipyparallel
# #pip install ipcluster
# #ipcluster nbextension enable
# #echo $PATH

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# !pwd
# Out:
# /home/jovyan/datacourse/data-wrangling/miniprojects

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[8000:8500]
# Out:
# [{'bnf_code': '0601022B0BBAEAV',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Glucophage SR_Tab 1000mg',
#   'nic': 17.04,
#   'act_cost': 15.8,
#   'quantity': 112},
#  {'bnf_code': '0601023ABAAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Liraglutide_Inj 6mg/ml 3ml PF Pen',
#   'nic': 274.68,
#   'act_cost': 254.43,
#   'quantity': 7},
#  {'bnf_code': '0601023ACAAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Saxagliptin_Tab 5mg',
#   'nic': 63.2,
#   'act_cost': 58.54,
#   'quantity': 56},
#  {'bnf_code': '0601023AEAAAAAA',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Linagliptin_Tab 5mg',
#   'nic': 399.12,
#   'act_cost': 369.64,
#   'quantity': 336},
#  {'bnf_code': '0601023AGAAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dapagliflozin_Tab 5mg',
#   'nic': 36.59,
#   'act_cost': 33.89,
#   'quantity': 28},
#  {'bnf_code': '0601023AGAAABAB',
#   'items': 32,
#   'practice': 'N81632',
#   'bnf_name': 'Dapagliflozin_Tab 10mg',
#   'nic': 1170.88,
#   'act_cost': 1084.34,
#   'quantity': 896},
#  {'bnf_code': '0601023AGBBABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Forxiga_Tab 10mg',
#   'nic': 36.59,
#   'act_cost': 33.89,
#   'quantity': 28},
#  {'bnf_code': '0601023AIAAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Lixisenatide_Inj 20mcg/0.2ml 3ml Pf Pen',
#   'nic': 57.93,
#   'act_cost': 53.64,
#   'quantity': 2},
#  {'bnf_code': '0601023B0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Pioglitazone HCl_Tab 15mg',
#   'nic': 1.84,
#   'act_cost': 1.72,
#   'quantity': 28},
#  {'bnf_code': '0601023B0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Pioglitazone HCl_Tab 30mg',
#   'nic': 3.98,
#   'act_cost': 3.7,
#   'quantity': 56},
#  {'bnf_code': '0601023B0AAACAC',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Pioglitazone HCl_Tab 45mg',
#   'nic': 13.1,
#   'act_cost': 12.19,
#   'quantity': 140},
#  {'bnf_code': '0601023R0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Repaglinide_Tab 1mg',
#   'nic': 3.27,
#   'act_cost': 3.14,
#   'quantity': 28},
#  {'bnf_code': '0601023X0AAAAAA',
#   'items': 29,
#   'practice': 'N81632',
#   'bnf_name': 'Sitagliptin_Tab 100mg',
#   'nic': 864.78,
#   'act_cost': 801.33,
#   'quantity': 728},
#  {'bnf_code': '0601023X0AAABAB',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Sitagliptin_Tab 50mg',
#   'nic': 199.56,
#   'act_cost': 184.81,
#   'quantity': 168},
#  {'bnf_code': '0601023X0AAACAC',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Sitagliptin_Tab 25mg',
#   'nic': 41.6,
#   'act_cost': 39.07,
#   'quantity': 35},
#  {'bnf_code': '0601023Y0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Exenatide_Inj 10mcg/0.04ml 2.4mlPfs(60D)',
#   'nic': 136.48,
#   'act_cost': 126.36,
#   'quantity': 2},
#  {'bnf_code': '0601040H0AAAEAE',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Glucagon_Inj (rys) 1mg Vl + Dil',
#   'nic': 11.52,
#   'act_cost': 10.69,
#   'quantity': 1},
#  {'bnf_code': '0601040H0BDAAAE',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'GlucaGen_HypoKit Inj 1mg Vl + Dil',
#   'nic': 11.52,
#   'act_cost': 10.69,
#   'quantity': 1},
#  {'bnf_code': '0601040I0AAADAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Glucose_Gel 40%',
#   'nic': 7.16,
#   'act_cost': 6.64,
#   'quantity': 75},
#  {'bnf_code': '0601040I0BBADAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoGel_Gel 40% (Original)',
#   'nic': 7.16,
#   'act_cost': 6.64,
#   'quantity': 75},
#  {'bnf_code': '0601060D0BJADA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'FreeStyle Optium (Reagent)_Strips',
#   'nic': 47.61,
#   'act_cost': 44.1,
#   'quantity': 150},
#  {'bnf_code': '0601060D0BTAAA0',
#   'items': 15,
#   'practice': 'N81632',
#   'bnf_name': 'Active (Reagent)_Strips',
#   'nic': 268.65,
#   'act_cost': 248.89,
#   'quantity': 1350},
#  {'bnf_code': '0601060D0BVAAA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Compact (Reagent)_Strips',
#   'nic': 65.56,
#   'act_cost': 60.72,
#   'quantity': 204},
#  {'bnf_code': '0601060D0BWABA0',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'FreeStyle Lite (Reagent)_Strips',
#   'nic': 255.52,
#   'act_cost': 236.64,
#   'quantity': 800},
#  {'bnf_code': '0601060D0CCAAA0',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Aviva (Reagent)_Strips',
#   'nic': 319.2,
#   'act_cost': 295.56,
#   'quantity': 1000},
#  {'bnf_code': '0601060D0CSAAA0',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Mobile (Reagent)_Strips',
#   'nic': 324.8,
#   'act_cost': 300.76,
#   'quantity': 1000},
#  {'bnf_code': '0601060D0CUABA0',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRx Nexus (Reagent)_Strips',
#   'nic': 179.1,
#   'act_cost': 165.92,
#   'quantity': 900},
#  {'bnf_code': '0601060D0CXAAA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Omnitest 3 (Reagent)_Strips',
#   'nic': 29.67,
#   'act_cost': 27.49,
#   'quantity': 150},
#  {'bnf_code': '0601060D0DGAAA0',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Contour Next (Reagent)_Strips',
#   'nic': 300.8,
#   'act_cost': 278.53,
#   'quantity': 1000},
#  {'bnf_code': '0601060D0DWAAA0',
#   'items': 9,
#   'practice': 'N81632',
#   'bnf_name': 'Performa (Reagent)_Strips',
#   'nic': 169.15,
#   'act_cost': 156.69,
#   'quantity': 850},
#  {'bnf_code': '0601060U0BHAAA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ketostix (Reagent)_Strips',
#   'nic': 6.12,
#   'act_cost': 5.7,
#   'quantity': 100},
#  {'bnf_code': '0601060W0BCAAA0',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'FreeStyle Optium B-Ketone Reagent_Strips',
#   'nic': 149.52,
#   'act_cost': 138.51,
#   'quantity': 70},
#  {'bnf_code': '0602010V0AABWBW',
#   'items': 97,
#   'practice': 'N81632',
#   'bnf_name': 'Levothyrox Sod_Tab 25mcg',
#   'nic': 264.85,
#   'act_cost': 247.98,
#   'quantity': 2548},
#  {'bnf_code': '0602010V0AABXBX',
#   'items': 107,
#   'practice': 'N81632',
#   'bnf_name': 'Levothyrox Sod_Tab 50mcg',
#   'nic': 166.52,
#   'act_cost': 157.57,
#   'quantity': 2807},
#  {'bnf_code': '0602010V0AABZBZ',
#   'items': 94,
#   'practice': 'N81632',
#   'bnf_name': 'Levothyrox Sod_Tab 100mcg',
#   'nic': 169.76,
#   'act_cost': 158.82,
#   'quantity': 2863},
#  {'bnf_code': '0602020D0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Carbimazole_Tab 5mg',
#   'nic': 69.85,
#   'act_cost': 64.89,
#   'quantity': 112},
#  {'bnf_code': '0603010I0AAACAC',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Fludrocort Acet_Tab 100mcg',
#   'nic': 126.0,
#   'act_cost': 116.98,
#   'quantity': 126},
#  {'bnf_code': '0603020G0AAADAD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Dexameth_Tab 2mg',
#   'nic': 71.99,
#   'act_cost': 66.87,
#   'quantity': 84},
#  {'bnf_code': '0603020J0AAADAD',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Hydrocort_Tab 10mg',
#   'nic': 906.44,
#   'act_cost': 839.62,
#   'quantity': 396},
#  {'bnf_code': '0603020T0AAAAAA',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Prednisolone_Tab 1mg',
#   'nic': 11.7,
#   'act_cost': 10.89,
#   'quantity': 420},
#  {'bnf_code': '0603020T0AAACAC',
#   'items': 42,
#   'practice': 'N81632',
#   'bnf_name': 'Prednisolone_Tab 5mg',
#   'nic': 51.42,
#   'act_cost': 51.02,
#   'quantity': 1654},
#  {'bnf_code': '0603020T0AAAFAF',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Prednisolone_Tab E/C 2.5mg',
#   'nic': 5.85,
#   'act_cost': 5.45,
#   'quantity': 140},
#  {'bnf_code': '0603020T0AAAGAG',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Prednisolone_Tab E/C 5mg',
#   'nic': 6.0,
#   'act_cost': 5.57,
#   'quantity': 140},
#  {'bnf_code': '0603020T0AABLBL',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Prednisolone_Oral Soln 5mg/5ml Ud',
#   'nic': 34.23,
#   'act_cost': 31.7,
#   'quantity': 30},
#  {'bnf_code': '0604011G0AAAIAI',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Estradiol_Tab 2mg',
#   'nic': 5.06,
#   'act_cost': 4.7,
#   'quantity': 84},
#  {'bnf_code': '0604011G0AABDBD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Estradiol_Tab 1mg',
#   'nic': 10.12,
#   'act_cost': 9.39,
#   'quantity': 168},
#  {'bnf_code': '0604011G0BFADBN',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Evorel 100_Patch',
#   'nic': 12.84,
#   'act_cost': 11.9,
#   'quantity': 24},
#  {'bnf_code': '0604011G0BMAABD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Elleste Solo_Tab 1mg',
#   'nic': 10.12,
#   'act_cost': 9.4,
#   'quantity': 168},
#  {'bnf_code': '0604011L0BHABAX',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Evorel Conti_Patch',
#   'nic': 19.5,
#   'act_cost': 18.16,
#   'quantity': 12},
#  {'bnf_code': '0604011L0BPAAAT',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Elleste Duet_Tab 2mg',
#   'nic': 24.54,
#   'act_cost': 23.02,
#   'quantity': 224},
#  {'bnf_code': '0604011L0BPABAW',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Elleste Duet_Tab 1mg',
#   'nic': 21.47,
#   'act_cost': 20.05,
#   'quantity': 196},
#  {'bnf_code': '0604011L0BPACAK',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Elleste Duet Conti_Tab',
#   'nic': 34.04,
#   'act_cost': 31.54,
#   'quantity': 168},
#  {'bnf_code': '0604011L0BRAABA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Kliovance_Tab',
#   'nic': 13.2,
#   'act_cost': 12.23,
#   'quantity': 84},
#  {'bnf_code': '0604011P0BBABAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Premarin_Tab 1.25mg',
#   'nic': 3.58,
#   'act_cost': 3.33,
#   'quantity': 84},
#  {'bnf_code': '0604011Y0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Tibolone_Tab 2.5mg',
#   'nic': 10.36,
#   'act_cost': 9.6,
#   'quantity': 28},
#  {'bnf_code': '0604011Y0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Livial_Tab 2.5mg',
#   'nic': 31.08,
#   'act_cost': 28.78,
#   'quantity': 84},
#  {'bnf_code': '0604012P0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Norethist_Tab 5mg',
#   'nic': 6.54,
#   'act_cost': 6.07,
#   'quantity': 90},
#  {'bnf_code': '0604012P0BCAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Utovlan_Tab 5mg',
#   'nic': 4.21,
#   'act_cost': 3.91,
#   'quantity': 90},
#  {'bnf_code': '0604020B0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Dutasteride_Cap 500mcg',
#   'nic': 27.26,
#   'act_cost': 25.46,
#   'quantity': 56},
#  {'bnf_code': '0604020C0AAAAAA',
#   'items': 26,
#   'practice': 'N81632',
#   'bnf_name': 'Finasteride_Tab 5mg',
#   'nic': 29.12,
#   'act_cost': 27.28,
#   'quantity': 728},
#  {'bnf_code': '0604020K0AABMBM',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Testosterone_Gel 2% (10mg per actuation)',
#   'nic': 86.01,
#   'act_cost': 79.65,
#   'quantity': 180},
#  {'bnf_code': '0604020K0BMAABM',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Tostran_Gel 2%',
#   'nic': 28.67,
#   'act_cost': 26.55,
#   'quantity': 60},
#  {'bnf_code': '0604020T0BDABAD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Nebido_Inj 1000mg/4ml Vl',
#   'nic': 174.22,
#   'act_cost': 161.31,
#   'quantity': 2},
#  {'bnf_code': '0605020E0AAADAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Desmopressin Acet_Tab 100mcg',
#   'nic': 39.25,
#   'act_cost': 36.45,
#   'quantity': 56},
#  {'bnf_code': '0606020A0AAACAC',
#   'items': 51,
#   'practice': 'N81632',
#   'bnf_name': 'Alendronic Acid_Tab 70mg',
#   'nic': 37.74,
#   'act_cost': 35.56,
#   'quantity': 204},
#  {'bnf_code': '0606020R0AAADAD',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Risedronate Sod_Tab 35mg',
#   'nic': 3.4,
#   'act_cost': 3.2,
#   'quantity': 16},
#  {'bnf_code': '0606020W0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ibandronic Acid_Tab 50mg',
#   'nic': 12.26,
#   'act_cost': 11.37,
#   'quantity': 56},
#  {'bnf_code': '0606020W0AAADAD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ibandronic Acid_Tab 150mg',
#   'nic': 2.26,
#   'act_cost': 2.12,
#   'quantity': 2},
#  {'bnf_code': '0606020X0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Strontium Ranelate_Susp Gran Sach 2g S/F',
#   'nic': 54.16,
#   'act_cost': 50.16,
#   'quantity': 56},
#  {'bnf_code': '0607010C0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Cabergoline_Tab 0.5mg',
#   'nic': 34.97,
#   'act_cost': 32.39,
#   'quantity': 8},
#  {'bnf_code': '0702010F0AAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Estriol_Crm 0.1% + Applic',
#   'nic': 13.35,
#   'act_cost': 12.39,
#   'quantity': 45},
#  {'bnf_code': '0702010F0AAACAC',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Estriol_Crm 0.01% + Applic',
#   'nic': 99.92,
#   'act_cost': 92.6,
#   'quantity': 320},
#  {'bnf_code': '0702010F0BCAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ovestin_Crm 1mg + Applic',
#   'nic': 4.45,
#   'act_cost': 4.13,
#   'quantity': 15},
#  {'bnf_code': '0702010G0AAAGAG',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Estradiol_Pess 10mcg',
#   'nic': 36.22,
#   'act_cost': 34.0,
#   'quantity': 52},
#  {'bnf_code': '0702010G0BCABAG',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Vagifem_Vag Tab 10mcg',
#   'nic': 58.52,
#   'act_cost': 54.53,
#   'quantity': 84},
#  {'bnf_code': '0702020F0AAAFAF',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Clotrimazole_Pess 500mg',
#   'nic': 5.76,
#   'act_cost': 5.36,
#   'quantity': 2},
#  {'bnf_code': '0702020F0AAAJAJ',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Clotrimazole_Crm 2%',
#   'nic': 4.46,
#   'act_cost': 4.14,
#   'quantity': 20},
#  {'bnf_code': '0702020F0AAAKAK',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Clotrimazole_Pess 500mg/Crm 2%',
#   'nic': 10.42,
#   'act_cost': 9.7,
#   'quantity': 2},
#  {'bnf_code': '0703010E0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ethinylest/Desogestrel_Tab 20mcg/150mcg',
#   'nic': 8.44,
#   'act_cost': 7.83,
#   'quantity': 63},
#  {'bnf_code': '0703010E0BIAAAB',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Gedarel_Tab 20/150mcg',
#   'nic': 15.24,
#   'act_cost': 14.15,
#   'quantity': 189},
#  {'bnf_code': '0703010F0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ethinylest/Desogestrel_Tab 30mcg/150mcg',
#   'nic': 7.1,
#   'act_cost': 6.59,
#   'quantity': 63},
#  {'bnf_code': '0703010F0AAACAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ethinylest/Levonorgest_Tab 30/150mcg',
#   'nic': 2.82,
#   'act_cost': 2.62,
#   'quantity': 63},
#  {'bnf_code': '0703010F0AAAJAJ',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ethinylestr/Drospirenone_Tab 30mcg/3mg',
#   'nic': 14.7,
#   'act_cost': 13.62,
#   'quantity': 63},
#  {'bnf_code': '0703010F0BEAAAC',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Microgynon 30_Tab',
#   'nic': 5.64,
#   'act_cost': 5.24,
#   'quantity': 126},
#  {'bnf_code': '0703010F0BEABAH',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Microgynon 30 ED_Tab',
#   'nic': 10.96,
#   'act_cost': 10.35,
#   'quantity': 308},
#  {'bnf_code': '0703010F0BIAAAF',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Loestrin 30_Tab',
#   'nic': 3.32,
#   'act_cost': 3.09,
#   'quantity': 63},
#  {'bnf_code': '0703010F0BPAAAC',
#   'items': 18,
#   'practice': 'N81632',
#   'bnf_name': 'Rigevidon_Tab',
#   'nic': 31.5,
#   'act_cost': 29.58,
#   'quantity': 1050},
#  {'bnf_code': '0703010F0BQAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Gedarel_Tab 30/150mcg',
#   'nic': 16.76,
#   'act_cost': 15.56,
#   'quantity': 252},
#  {'bnf_code': '0703010G0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ethinylest/Norethist_Tab 35mcg/500mcg',
#   'nic': 1.99,
#   'act_cost': 1.85,
#   'quantity': 63},
#  {'bnf_code': '0703010G0BFAAAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Cilest_Tab',
#   'nic': 7.16,
#   'act_cost': 6.64,
#   'quantity': 63},
#  {'bnf_code': '0703021N0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Norethist_Tab 350mcg',
#   'nic': 3.6,
#   'act_cost': 3.36,
#   'quantity': 168},
#  {'bnf_code': '0703021N0BBAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Micronor_Tab 350mcg',
#   'nic': 3.6,
#   'act_cost': 3.36,
#   'quantity': 168},
#  {'bnf_code': '0703021Q0AAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Desogestrel_Tab 75mcg',
#   'nic': 6.51,
#   'act_cost': 6.06,
#   'quantity': 252},
#  {'bnf_code': '0703021Q0BBAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Cerazette_Tab 75mcg',
#   'nic': 28.65,
#   'act_cost': 26.55,
#   'quantity': 252},
#  {'bnf_code': '0703021Q0BDAAAA',
#   'items': 44,
#   'practice': 'N81632',
#   'bnf_name': 'Cerelle_Tab 75mcg',
#   'nic': 144.67,
#   'act_cost': 134.98,
#   'quantity': 3472},
#  {'bnf_code': '0703022M0BBABAB',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Depo-Provera_Inj 150mg/ml 1ml Pfs',
#   'nic': 48.08,
#   'act_cost': 44.51,
#   'quantity': 8},
#  {'bnf_code': '0703022P0BCAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Nexplanon_Implant 68mg',
#   'nic': 83.43,
#   'act_cost': 77.25,
#   'quantity': 1},
#  {'bnf_code': '0704010A0AAADAD',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Alfuzosin HCl_Tab 10mg M/R',
#   'nic': 35.87,
#   'act_cost': 33.45,
#   'quantity': 86},
#  {'bnf_code': '0704010U0AAAAAA',
#   'items': 61,
#   'practice': 'N81632',
#   'bnf_name': 'Tamsulosin HCl_Cap 400mcg M/R',
#   'nic': 216.01,
#   'act_cost': 204.72,
#   'quantity': 1666},
#  {'bnf_code': '0704010V0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Combodart_Cap 0.5mg/0.4mg',
#   'nic': 22.18,
#   'act_cost': 20.65,
#   'quantity': 28},
#  {'bnf_code': '0704020AAAAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Duloxetine HCl_Cap G/R 20mg',
#   'nic': 5.88,
#   'act_cost': 5.46,
#   'quantity': 56},
#  {'bnf_code': '0704020AAAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Duloxetine HCl_Cap G/R 40mg',
#   'nic': 2.45,
#   'act_cost': 2.38,
#   'quantity': 28},
#  {'bnf_code': '0704020ABAAAAAA',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Solifenacin_Tab 5mg',
#   'nic': 189.66,
#   'act_cost': 175.84,
#   'quantity': 206},
#  {'bnf_code': '0704020ABAAABAB',
#   'items': 9,
#   'practice': 'N81632',
#   'bnf_name': 'Solifenacin_Tab 10mg',
#   'nic': 203.51,
#   'act_cost': 189.31,
#   'quantity': 170},
#  {'bnf_code': '0704020ACAAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Darifenacin Hydrob_Tab 7.5mg M/R',
#   'nic': 76.44,
#   'act_cost': 70.8,
#   'quantity': 84},
#  {'bnf_code': '0704020ACAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Darifenacin Hydrob_Tab 15mg M/R',
#   'nic': 25.48,
#   'act_cost': 23.6,
#   'quantity': 28},
#  {'bnf_code': '0704020ADAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Fesoterodine Fumar_Tab 8mg M/R',
#   'nic': 25.78,
#   'act_cost': 23.88,
#   'quantity': 28},
#  {'bnf_code': '0704020AEAAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Mirabegron_Tab 25mg M/R',
#   'nic': 87.0,
#   'act_cost': 80.58,
#   'quantity': 90},
#  {'bnf_code': '0704020AEAAABAB',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Mirabegron_Tab 50mg M/R',
#   'nic': 230.07,
#   'act_cost': 213.19,
#   'quantity': 238},
#  {'bnf_code': '0704020J0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Oxybutynin HCl_Tab 2.5mg',
#   'nic': 0.58,
#   'act_cost': 0.65,
#   'quantity': 28},
#  {'bnf_code': '0704020J0AAACAC',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Oxybutynin HCl_Tab 5mg',
#   'nic': 2.24,
#   'act_cost': 2.2,
#   'quantity': 84},
#  {'bnf_code': '0704020N0AAABAB',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Tolterodine_Tab 2mg',
#   'nic': 5.43,
#   'act_cost': 5.07,
#   'quantity': 168},
#  {'bnf_code': '0704020N0BFAAAC',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Neditol XL_Cap 4mg',
#   'nic': 25.78,
#   'act_cost': 23.89,
#   'quantity': 56},
#  {'bnf_code': '0704020Z0BBABAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Regurin XL_Cap 60mg',
#   'nic': 23.05,
#   'act_cost': 21.35,
#   'quantity': 28},
#  {'bnf_code': '0704050AAAAACAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Vardenafil_Tab 20mg',
#   'nic': 23.48,
#   'act_cost': 21.75,
#   'quantity': 4},
#  {'bnf_code': '0704050R0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Tadalafil_Tab 10mg',
#   'nic': 28.88,
#   'act_cost': 26.75,
#   'quantity': 4},
#  {'bnf_code': '0704050R0AAABAB',
#   'items': 9,
#   'practice': 'N81632',
#   'bnf_name': 'Tadalafil_Tab 20mg',
#   'nic': 259.92,
#   'act_cost': 240.73,
#   'quantity': 36},
#  {'bnf_code': '0704050Z0AAAAAA',
#   'items': 13,
#   'practice': 'N81632',
#   'bnf_name': 'Sildenafil_Tab 50mg',
#   'nic': 18.06,
#   'act_cost': 16.89,
#   'quantity': 84},
#  {'bnf_code': '0704050Z0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Sildenafil_Tab 25mg',
#   'nic': 1.56,
#   'act_cost': 1.47,
#   'quantity': 8},
#  {'bnf_code': '0704050Z0AAACAC',
#   'items': 29,
#   'practice': 'N81632',
#   'bnf_name': 'Sildenafil_Tab 100mg',
#   'nic': 48.88,
#   'act_cost': 45.61,
#   'quantity': 208},
#  {'bnf_code': '0801030L0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Mercaptopurine_Tab 50mg',
#   'nic': 55.05,
#   'act_cost': 51.08,
#   'quantity': 28},
#  {'bnf_code': '0801050P0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hydroxycarbamide_Cap 500mg',
#   'nic': 8.24,
#   'act_cost': 7.74,
#   'quantity': 68},
#  {'bnf_code': '0802010G0AAADAD',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Azathioprine_Tab 25mg',
#   'nic': 4.98,
#   'act_cost': 4.65,
#   'quantity': 84},
#  {'bnf_code': '0802010G0AAAEAE',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Azathioprine_Tab 50mg',
#   'nic': 28.76,
#   'act_cost': 27.57,
#   'quantity': 728},
#  {'bnf_code': '0802010M0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Mycophenolate Mofetil_Tab 500mg',
#   'nic': 13.82,
#   'act_cost': 12.91,
#   'quantity': 112},
#  {'bnf_code': '0803041B0AAAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Anastrozole_Tab 1mg',
#   'nic': 5.4,
#   'act_cost': 5.05,
#   'quantity': 140},
#  {'bnf_code': '0803041C0AAAAAA',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Exemestane_Tab 25mg',
#   'nic': 46.08,
#   'act_cost': 43.02,
#   'quantity': 144},
#  {'bnf_code': '0803041L0AAAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Letrozole_Tab 2.5mg',
#   'nic': 10.08,
#   'act_cost': 9.39,
#   'quantity': 112},
#  {'bnf_code': '0803041S0AAABAB',
#   'items': 13,
#   'practice': 'N81632',
#   'bnf_name': 'Tamoxifen Cit_Tab 20mg',
#   'nic': 36.68,
#   'act_cost': 34.52,
#   'quantity': 382},
#  {'bnf_code': '0803042A0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Bicalutamide_Tab 50mg',
#   'nic': 1.79,
#   'act_cost': 1.67,
#   'quantity': 28},
#  {'bnf_code': '0803042A0AAABAB',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Bicalutamide_Tab 150mg',
#   'nic': 22.4,
#   'act_cost': 20.79,
#   'quantity': 140},
#  {'bnf_code': '0803042K0BBAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Zoladex_Implant 3.6mg SafeSystem Pfs',
#   'nic': 130.0,
#   'act_cost': 120.34,
#   'quantity': 2},
#  {'bnf_code': '0803042K0BBABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Zoladex LA_Implant 10.8mg SafeSystem Pfs',
#   'nic': 235.0,
#   'act_cost': 217.55,
#   'quantity': 1},
#  {'bnf_code': '0803042N0BBADAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Prostap 3_DCS Inj 11.25mg Dil + Pfs',
#   'nic': 225.72,
#   'act_cost': 208.96,
#   'quantity': 1},
#  {'bnf_code': '0901011F0AAAEAE',
#   'items': 30,
#   'practice': 'N81632',
#   'bnf_name': 'Ferr Fumar_Tab 210mg',
#   'nic': 68.82,
#   'act_cost': 66.3,
#   'quantity': 1652},
#  {'bnf_code': '0901011P0AAACAC',
#   'items': 18,
#   'practice': 'N81632',
#   'bnf_name': 'Ferr Sulf_Tab 200mg',
#   'nic': 55.33,
#   'act_cost': 51.97,
#   'quantity': 842},
#  {'bnf_code': '0901011W0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Sytron_Elix 190mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.88,
#   'quantity': 100},
#  {'bnf_code': '0901020D0AAAEAE',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'Cyanocobalamin_Tab 50mcg',
#   'nic': 142.74,
#   'act_cost': 133.15,
#   'quantity': 794},
#  {'bnf_code': '0901020D0AAAHAH',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Cyanocobalamin_Tab 1mg M/R',
#   'nic': 2.45,
#   'act_cost': 2.38,
#   'quantity': 28},
#  {'bnf_code': '0901020G0AAAGAG',
#   'items': 52,
#   'practice': 'N81632',
#   'bnf_name': 'Folic Acid_Tab 5mg',
#   'nic': 29.93,
#   'act_cost': 31.37,
#   'quantity': 930},
#  {'bnf_code': '0901020G0AABFBF',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Folic Acid_Tab 400mcg',
#   'nic': 0.84,
#   'act_cost': 0.89,
#   'quantity': 28},
#  {'bnf_code': '0901020N0AAABAB',
#   'items': 33,
#   'practice': 'N81632',
#   'bnf_name': 'Hydroxocobalamin_Inj 1mg/ml 1ml Amp',
#   'nic': 46.86,
#   'act_cost': 43.6,
#   'quantity': 33},
#  {'bnf_code': '0902011U0BIAAAF',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'Sando-K_Tab Eff 470mg',
#   'nic': 67.32,
#   'act_cost': 63.1,
#   'quantity': 880},
#  {'bnf_code': '0902012H0BBAFAE',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dioralyte_Pdr Sach (Citrus)',
#   'nic': 3.36,
#   'act_cost': 3.22,
#   'quantity': 10},
#  {'bnf_code': '0902012H0BBAGAE',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dioralyte_Pdr Sach (Blkcurrant)',
#   'nic': 100.8,
#   'act_cost': 93.33,
#   'quantity': 300},
#  {'bnf_code': '0902013S0AAACAC',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Sod Bicarb_Cap 500mg',
#   'nic': 28.14,
#   'act_cost': 26.1,
#   'quantity': 784},
#  {'bnf_code': '0904010H0BDAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Juvela_G/F Fibre Loaf Brown (Cut)',
#   'nic': 14.16,
#   'act_cost': 13.12,
#   'quantity': 1600},
#  {'bnf_code': '0904010H0BJAQAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Glutafin Select_G/F Fresh Loaf Brown(Cut',
#   'nic': 27.44,
#   'act_cost': 25.42,
#   'quantity': 3200},
#  {'bnf_code': '0904010H0BJAUAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Glutafin_G/F Fibre Roll x 4 P/bake',
#   'nic': 14.72,
#   'act_cost': 13.64,
#   'quantity': 800},
#  {'bnf_code': '0904010H0BSADAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Genius_G/F Bread Brown Sandwich (Cut)',
#   'nic': 44.76,
#   'act_cost': 41.45,
#   'quantity': 6420},
#  {'bnf_code': '0904010K0AAAFAF',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'Glucose_Tab',
#   'nic': 11.66,
#   'act_cost': 10.93,
#   'quantity': 284},
#  {'bnf_code': '090401080BLABBD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Juvela_G/F W/F Fusilli',
#   'nic': 36.05,
#   'act_cost': 33.4,
#   'quantity': 2500},
#  {'bnf_code': '090401080BLADBD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Juvela_G/F W/F Spaghetti',
#   'nic': 14.42,
#   'act_cost': 13.36,
#   'quantity': 1000},
#  {'bnf_code': '090402000BBAJA0',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Fortisip Bottle_Liq (8 Flav)',
#   'nic': 78.4,
#   'act_cost': 72.68,
#   'quantity': 11200},
#  {'bnf_code': '090402000BBHWA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Optifibre_Pdr',
#   'nic': 20.56,
#   'act_cost': 19.06,
#   'quantity': 500},
#  {'bnf_code': '090402000BBJQA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure Plus Fibre_Liq Feed (5 Flav)',
#   'nic': 117.16,
#   'act_cost': 108.48,
#   'quantity': 11600},
#  {'bnf_code': '090402000BBLJA0',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Foodlink_Complete Pdr (4 Flav)',
#   'nic': 153.72,
#   'act_cost': 142.35,
#   'quantity': 14364},
#  {'bnf_code': '090402000BBNTA0',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure Plus Juce_Liq Feed (6 Flav)',
#   'nic': 110.32,
#   'act_cost': 102.28,
#   'quantity': 12320},
#  {'bnf_code': '090402000BBQKA0',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Sbery)',
#   'nic': 14.0,
#   'act_cost': 13.0,
#   'quantity': 20},
#  {'bnf_code': '090402000BBQLA0',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Choc)',
#   'nic': 16.8,
#   'act_cost': 15.59,
#   'quantity': 24},
#  {'bnf_code': '090402000BBQMA0',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Vanilla)',
#   'nic': 11.2,
#   'act_cost': 10.41,
#   'quantity': 16},
#  {'bnf_code': '090402000BBRAA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Milk)',
#   'nic': 5.6,
#   'act_cost': 5.21,
#   'quantity': 8},
#  {'bnf_code': '090402000BBRBA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Complan_Shake Pdr Sach 57g (Banana)',
#   'nic': 11.2,
#   'act_cost': 10.39,
#   'quantity': 16},
#  {'bnf_code': '090402000BBRRA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure Plus_Milkshake Style Liq(10 Flav)',
#   'nic': 56.0,
#   'act_cost': 51.87,
#   'quantity': 8800},
#  {'bnf_code': '090402000BBRZA0',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure TwoCal_Liq (4 Flav)',
#   'nic': 186.48,
#   'act_cost': 172.73,
#   'quantity': 16800},
#  {'bnf_code': '090402000BBTDA0',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Peptamen Junior Advance_Liq',
#   'nic': 466.2,
#   'act_cost': 431.6,
#   'quantity': 30000},
#  {'bnf_code': '090402000BBVNA0',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure Shake_Oral Pdr Sach 57g (Banana)',
#   'nic': 10.92,
#   'act_cost': 10.12,
#   'quantity': 14},
#  {'bnf_code': '090402000BBVTA0',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Ensure Compact_Liq (4 Flav)',
#   'nic': 394.4,
#   'act_cost': 365.17,
#   'quantity': 34000},
#  {'bnf_code': '0905011D0AAAJAJ',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Calc Carb_Tab Chble 1.25g (500mg) S/F',
#   'nic': 9.7,
#   'act_cost': 9.54,
#   'quantity': 104},
#  {'bnf_code': '0905011D0AAAKAK',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Calc Carb_Tab Chble 1.5g (600mg) S/F',
#   'nic': 4.18,
#   'act_cost': 3.98,
#   'quantity': 48},
#  {'bnf_code': '0905011D0BCAAAJ',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Calcichew_Tab Chble 1.25g (500mg)',
#   'nic': 7.84,
#   'act_cost': 7.37,
#   'quantity': 84},
#  {'bnf_code': '0906026M0AAAFAF',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Thiamine HCl_Tab 50mg',
#   'nic': 12.0,
#   'act_cost': 11.45,
#   'quantity': 168},
#  {'bnf_code': '0906026M0AAAGAG',
#   'items': 38,
#   'practice': 'N81632',
#   'bnf_name': 'Thiamine HCl_Tab 100mg',
#   'nic': 248.0,
#   'act_cost': 233.76,
#   'quantity': 2480},
#  {'bnf_code': '0906027G0AAABAB',
#   'items': 46,
#   'practice': 'N81632',
#   'bnf_name': 'Vit B Co Strong_Tab',
#   'nic': 157.82,
#   'act_cost': 147.17,
#   'quantity': 2926},
#  {'bnf_code': '0906031C0AAAFAF',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ascorbic Acid_Tab 50mg',
#   'nic': 30.1,
#   'act_cost': 27.9,
#   'quantity': 56},
#  {'bnf_code': '0906040B0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Alfacalcidol_Cap 250ng',
#   'nic': 6.86,
#   'act_cost': 6.38,
#   'quantity': 60},
#  {'bnf_code': '0906040B0AAAIAI',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Alfacalcidol_Cap 500ng',
#   'nic': 14.52,
#   'act_cost': 13.46,
#   'quantity': 60},
#  {'bnf_code': '0906040G0AAANAN',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal_Cap 800u',
#   'nic': 7.2,
#   'act_cost': 6.69,
#   'quantity': 60},
#  {'bnf_code': '0906040G0AABGBG',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal_Tab 1 000u',
#   'nic': 2.95,
#   'act_cost': 2.74,
#   'quantity': 28},
#  {'bnf_code': '0906040G0AABUBU',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal & Calc_Tab Chble 200u/1.25g',
#   'nic': 7.06,
#   'act_cost': 6.98,
#   'quantity': 92},
#  {'bnf_code': '0906040G0AABWBW',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal & Calc_Tab Chble 400u/1.25g',
#   'nic': 41.27,
#   'act_cost': 38.84,
#   'quantity': 584},
#  {'bnf_code': '0906040G0AABYBY',
#   'items': 20,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal & Calc_Tab Chble 400u/1.5g',
#   'nic': 73.8,
#   'act_cost': 69.07,
#   'quantity': 1132},
#  {'bnf_code': '0906040G0AACBCB',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal & Calc_Tab Eff 400u/1.5g (Lem)',
#   'nic': 17.98,
#   'act_cost': 17.12,
#   'quantity': 168},
#  {'bnf_code': '0906040G0AACDCD',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Colecal & Calc_Tab 200u/750mg',
#   'nic': 5.9,
#   'act_cost': 5.48,
#   'quantity': 224},
#  {'bnf_code': '0906040G0BIABBH',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Pro D3_Cap 1 000u',
#   'nic': 6.99,
#   'act_cost': 6.48,
#   'quantity': 30},
#  {'bnf_code': '0906040G0BIAEDR',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Pro D3_Cap 20 000u',
#   'nic': 5.34,
#   'act_cost': 5.17,
#   'quantity': 8},
#  {'bnf_code': '0906040G0BKAABS',
#   'items': 13,
#   'practice': 'N81632',
#   'bnf_name': 'Accrete D3_Tab',
#   'nic': 33.81,
#   'act_cost': 32.36,
#   'quantity': 688},
#  {'bnf_code': '0906040G0BNAABY',
#   'items': 18,
#   'practice': 'N81632',
#   'bnf_name': 'Adcal-D3_Tab Chble (Tutti-Frutti)',
#   'nic': 64.76,
#   'act_cost': 60.48,
#   'quantity': 992},
#  {'bnf_code': '0906040G0BNABCA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Adcal-D3_Tab Chble (Lem)',
#   'nic': 7.3,
#   'act_cost': 6.78,
#   'quantity': 112},
#  {'bnf_code': '0906040G0BQAABW',
#   'items': 15,
#   'practice': 'N81632',
#   'bnf_name': 'Calceos_Tab Chble 500mg/400u',
#   'nic': 53.35,
#   'act_cost': 50.38,
#   'quantity': 825},
#  {'bnf_code': '0906040G0BRAABU',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Calcichew D3_Tab Chble',
#   'nic': 7.99,
#   'act_cost': 7.62,
#   'quantity': 104},
#  {'bnf_code': '0906040G0BRABBW',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Calcichew D3 Fte_Tab Chble',
#   'nic': 3.96,
#   'act_cost': 3.78,
#   'quantity': 56},
#  {'bnf_code': '0906040G0BXAAAN',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Fultium-D3_Cap 800u',
#   'nic': 21.12,
#   'act_cost': 20.5,
#   'quantity': 176},
#  {'bnf_code': '0906040G0CGAADR',
#   'items': 14,
#   'practice': 'N81632',
#   'bnf_name': 'Hux D3_Cap 20 000u',
#   'nic': 21.07,
#   'act_cost': 20.79,
#   'quantity': 161},
#  {'bnf_code': '0906040G0CJAACS',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Desunin_Tab 800u',
#   'nic': 6.96,
#   'act_cost': 6.57,
#   'quantity': 58},
#  {'bnf_code': '0906050P0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Vit E_Cap 200u',
#   'nic': 4.53,
#   'act_cost': 4.31,
#   'quantity': 56},
#  {'bnf_code': '0906060L0AAACAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Menadiol Sod Phos_Tab 10mg',
#   'nic': 52.05,
#   'act_cost': 48.3,
#   'quantity': 28},
#  {'bnf_code': '0906070T0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Vit_Cap',
#   'nic': 1.73,
#   'act_cost': 1.71,
#   'quantity': 112},
#  {'bnf_code': '090607000BBAZAG',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Dalivit_Dps',
#   'nic': 12.38,
#   'act_cost': 11.48,
#   'quantity': 50},
#  {'bnf_code': '090607000BBEGA1',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Forceval_Cap',
#   'nic': 29.31,
#   'act_cost': 27.49,
#   'quantity': 114},
#  {'bnf_code': '090607000BBLCA0',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Forceval_Tab Solb',
#   'nic': 19.1,
#   'act_cost': 17.71,
#   'quantity': 60},
#  {'bnf_code': '091000000BBVGA0',
#   'items': 19,
#   'practice': 'N81632',
#   'bnf_name': 'Preservision_Lutein Cap',
#   'nic': 171.42,
#   'act_cost': 160.13,
#   'quantity': 1092},
#  {'bnf_code': '1001010AHAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Celecoxib_Cap 200mg',
#   'nic': 6.05,
#   'act_cost': 5.71,
#   'quantity': 112},
#  {'bnf_code': '1001010AJAAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Etoricoxib_Tab 90mg',
#   'nic': 45.92,
#   'act_cost': 42.54,
#   'quantity': 56},
#  {'bnf_code': '1001010C0AAALAL',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Diclofenac Sod_Tab 75mg M/R',
#   'nic': 11.31,
#   'act_cost': 10.48,
#   'quantity': 56},
#  {'bnf_code': '1001010C0AAAWAW',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Diclofenac Sod_Cap 75mg M/R',
#   'nic': 9.69,
#   'act_cost': 8.98,
#   'quantity': 56},
#  {'bnf_code': '1001010J0AAACAC',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Ibuprofen_Oral Susp 100mg/5ml',
#   'nic': 17.76,
#   'act_cost': 16.47,
#   'quantity': 1000},
#  {'bnf_code': '1001010J0AAAEAE',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Ibuprofen_Tab 400mg',
#   'nic': 11.29,
#   'act_cost': 10.72,
#   'quantity': 315},
#  {'bnf_code': '1001010K0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Indometacin_Cap 50mg',
#   'nic': 5.44,
#   'act_cost': 5.06,
#   'quantity': 112},
#  {'bnf_code': '1001010P0AAADAD',
#   'items': 14,
#   'practice': 'N81632',
#   'bnf_name': 'Naproxen_Tab 250mg',
#   'nic': 26.04,
#   'act_cost': 24.28,
#   'quantity': 784},
#  {'bnf_code': '1001010P0AAAEAE',
#   'items': 44,
#   'practice': 'N81632',
#   'bnf_name': 'Naproxen_Tab 500mg',
#   'nic': 107.92,
#   'act_cost': 100.44,
#   'quantity': 2128},
#  {'bnf_code': '1001022K0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Methylpred Acet_Inj 40mg/ml 1ml Vl',
#   'nic': 3.44,
#   'act_cost': 3.18,
#   'quantity': 1},
#  {'bnf_code': '1001030C0AAAAAA',
#   'items': 11,
#   'practice': 'N81632',
#   'bnf_name': 'Hydroxychlor Sulf_Tab 200mg',
#   'nic': 20.99,
#   'act_cost': 20.57,
#   'quantity': 346},
#  {'bnf_code': '1001030L0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Leflunomide_Tab 20mg',
#   'nic': 9.5,
#   'act_cost': 8.81,
#   'quantity': 30},
#  {'bnf_code': '1001030U0AAABAB',
#   'items': 18,
#   'practice': 'N81632',
#   'bnf_name': 'Methotrexate_Tab 2.5mg',
#   'nic': 24.52,
#   'act_cost': 24.52,
#   'quantity': 388},
#  {'bnf_code': '1001040C0AAAAAA',
#   'items': 33,
#   'practice': 'N81632',
#   'bnf_name': 'Allopurinol_Tab 100mg',
#   'nic': 30.22,
#   'act_cost': 29.09,
#   'quantity': 1099},
#  {'bnf_code': '1001040C0AAABAB',
#   'items': 17,
#   'practice': 'N81632',
#   'bnf_name': 'Allopurinol_Tab 300mg',
#   'nic': 15.3,
#   'act_cost': 14.39,
#   'quantity': 504},
#  {'bnf_code': '1001040G0AAACAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Colchicine_Tab 500mcg',
#   'nic': 8.0,
#   'act_cost': 7.52,
#   'quantity': 56},
#  {'bnf_code': '1002020C0AAAIAI',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Baclofen_Tab 10mg',
#   'nic': 5.17,
#   'act_cost': 5.13,
#   'quantity': 280},
#  {'bnf_code': '1002020T0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Tizanidine HCl_Tab 4mg',
#   'nic': 26.78,
#   'act_cost': 24.9,
#   'quantity': 90},
#  {'bnf_code': '1003020AAAAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Capsaicin_Crm 0.075%',
#   'nic': 29.16,
#   'act_cost': 27.02,
#   'quantity': 90},
#  {'bnf_code': '1003020AAAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Capsaicin_Crm 0.025%',
#   'nic': 35.42,
#   'act_cost': 32.8,
#   'quantity': 90},
#  {'bnf_code': '1003020I0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Diethylamine Sal_Crm 10% BP',
#   'nic': 2.98,
#   'act_cost': 2.77,
#   'quantity': 100},
#  {'bnf_code': '1003020P0AAACAC',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Ibuprofen_Gel 5%',
#   'nic': 20.79,
#   'act_cost': 19.31,
#   'quantity': 450},
#  {'bnf_code': '1003020P0AAAIAI',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Ibuprofen_Gel 10%',
#   'nic': 14.76,
#   'act_cost': 13.7,
#   'quantity': 300},
#  {'bnf_code': '1003020P0BGAAAC',
#   'items': 22,
#   'practice': 'N81632',
#   'bnf_name': 'Fenbid_Gel 5%',
#   'nic': 42.4,
#   'act_cost': 39.52,
#   'quantity': 1990},
#  {'bnf_code': '1003020P0BGABAI',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Fenbid Fte_Gel 10%',
#   'nic': 12.0,
#   'act_cost': 11.15,
#   'quantity': 300},
#  {'bnf_code': '100302010AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Ketoprofen_Gel 2.5%',
#   'nic': 3.28,
#   'act_cost': 3.05,
#   'quantity': 100},
#  {'bnf_code': '1103010C0AAAAAA',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'Chloramphen_Eye Dps 0.5%',
#   'nic': 10.64,
#   'act_cost': 9.94,
#   'quantity': 70},
#  {'bnf_code': '1103010C0AAADAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Chloramphen_Eye Oint 1%',
#   'nic': 2.27,
#   'act_cost': 2.11,
#   'quantity': 4},
#  {'bnf_code': '1103010H0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Fusidic Acid_Viscous Eye Dps 1%',
#   'nic': 58.12,
#   'act_cost': 53.82,
#   'quantity': 10},
#  {'bnf_code': '1104010K0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Fluorome_Eye Dps 0.1%',
#   'nic': 1.71,
#   'act_cost': 1.6,
#   'quantity': 5},
#  {'bnf_code': '1104010R0BBAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Pred Fte_Eye Dps 1%',
#   'nic': 12.74,
#   'act_cost': 11.84,
#   'quantity': 35},
#  {'bnf_code': '1104020N0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Nedocromil Sod_Eye Dps Aq 2%',
#   'nic': 2.86,
#   'act_cost': 2.66,
#   'quantity': 5},
#  {'bnf_code': '1104020T0AAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Sod Cromoglicate_Eye Dps Aq 2%',
#   'nic': 7.05,
#   'act_cost': 6.57,
#   'quantity': 39},
#  {'bnf_code': '1104020Z0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Olopatadine_Eye Dps 1mg/ml',
#   'nic': 4.68,
#   'act_cost': 4.34,
#   'quantity': 5},
#  {'bnf_code': '1104020Z0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Opatanol_Eye Dps 1mg/ml',
#   'nic': 4.68,
#   'act_cost': 4.34,
#   'quantity': 5},
#  {'bnf_code': '1105000B0AAAJAJ',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Atrop Sulf_Eye Dps 1% Ud',
#   'nic': 45.3,
#   'act_cost': 41.95,
#   'quantity': 60},
#  {'bnf_code': '1106000ABAAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dorzolamide/Timolol_EyeDps2/0.5% 0.2mlUd',
#   'nic': 28.59,
#   'act_cost': 26.48,
#   'quantity': 60},
#  {'bnf_code': '1106000ABBBABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Cosopt_Eye Dps 0.2ml Ud P/F',
#   'nic': 57.18,
#   'act_cost': 52.95,
#   'quantity': 120},
#  {'bnf_code': '1106000ACAAAAAA',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'Brinzolamide_Eye Dps 10mg/ml',
#   'nic': 29.54,
#   'act_cost': 27.48,
#   'quantity': 70},
#  {'bnf_code': '1106000ADAAAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Latanoprost/Timolol_Eye Dps 50mcg/5mg/ml',
#   'nic': 8.28,
#   'act_cost': 7.72,
#   'quantity': 8},
#  {'bnf_code': '1106000AFAAABAB',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Bimatoprost_Eye Dps 100mcg/ml',
#   'nic': 58.55,
#   'act_cost': 54.27,
#   'quantity': 15},
#  {'bnf_code': '1106000AFAAACAC',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Bimatoprost_Eye Dps 300mcg/ml 0.4ml Ud',
#   'nic': 27.5,
#   'act_cost': 25.48,
#   'quantity': 60},
#  {'bnf_code': '1106000AHBBAAAA',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'DuoTrav_Eye Dps 40mcg/ml / 5mg/ml',
#   'nic': 55.8,
#   'act_cost': 51.71,
#   'quantity': 8},
#  {'bnf_code': '1106000AIAAAAAA',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Bimatoprost/Timolol_Eye Dps 300mcg/5mg',
#   'nic': 97.65,
#   'act_cost': 90.46,
#   'quantity': 21},
#  {'bnf_code': '1106000AIBBAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Ganfort_Eye Dps 300mcg/5mg',
#   'nic': 41.85,
#   'act_cost': 38.78,
#   'quantity': 9},
#  {'bnf_code': '1106000AKBBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Saflutan_Eye Dps 15mcg/ml 0.3ml Ud',
#   'nic': 24.4,
#   'act_cost': 22.6,
#   'quantity': 60},
#  {'bnf_code': '1106000ALAAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Brinzolamide/Brimonidine_EyeDps10mg2mgml',
#   'nic': 9.23,
#   'act_cost': 8.56,
#   'quantity': 5},
#  {'bnf_code': '1106000ALBBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Simbrinza_Eye Dps 10mg/ml / 2mg/ml',
#   'nic': 9.23,
#   'act_cost': 8.56,
#   'quantity': 5},
#  {'bnf_code': '1106000L0AAAAAA',
#   'items': 24,
#   'practice': 'N81632',
#   'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml',
#   'nic': 42.0,
#   'act_cost': 39.17,
#   'quantity': 66},
#  {'bnf_code': '1106000L0AAABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Latanoprost_Eye Dps 50mcg/ml 0.2mlUd P/F',
#   'nic': 8.49,
#   'act_cost': 7.87,
#   'quantity': 30},
#  {'bnf_code': '1106000Z0AAALAL',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Timolol_Eye Dps 0.5% Ud',
#   'nic': 19.3,
#   'act_cost': 17.88,
#   'quantity': 60},
#  {'bnf_code': '1106000Z0AAAPAP',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Timolol_Gel Eye Dps 0.25%',
#   'nic': 6.24,
#   'act_cost': 5.79,
#   'quantity': 5},
#  {'bnf_code': '1106000Z0BBAEAP',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Timoptol-LA_Ophth Gel-Forming Soln 0.25%',
#   'nic': 9.36,
#   'act_cost': 8.69,
#   'quantity': 7},
#  {'bnf_code': '1108010B0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Carbomer 980_Gel Eye Dps 0.2%',
#   'nic': 5.6,
#   'act_cost': 5.2,
#   'quantity': 20},
#  {'bnf_code': '1108010B0BBAAAB',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Viscotears_Liq Gel 2mg/g',
#   'nic': 9.54,
#   'act_cost': 8.91,
#   'quantity': 60},
#  {'bnf_code': '1108010D0BCAAAC',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Celluvisc_Eye Dps 1% 0.4ml Ud',
#   'nic': 22.99,
#   'act_cost': 21.32,
#   'quantity': 180},
#  {'bnf_code': '1108010F0AAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Hypromellose_Eye Dps 0.3%',
#   'nic': 4.26,
#   'act_cost': 3.99,
#   'quantity': 30},
#  {'bnf_code': '1108010F0AAABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Hypromellose_Eye Dps 0.5%',
#   'nic': 1.62,
#   'act_cost': 1.52,
#   'quantity': 20},
#  {'bnf_code': '1201010G0AAACAC',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Gentamicin/Hydrocort Acet_Ear Dps 0.3/1%',
#   'nic': 23.92,
#   'act_cost': 22.16,
#   'quantity': 10},
#  {'bnf_code': '120101050BCAAAB',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Otomize_Ear Spy 5ml',
#   'nic': 39.24,
#   'act_cost': 36.48,
#   'quantity': 12},
#  {'bnf_code': '1202010C0AAAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Beclomet Diprop_Nsl Spy 50mcg (200 D)',
#   'nic': 4.2,
#   'act_cost': 3.92,
#   'quantity': 2},
#  {'bnf_code': '1202010C0BBABAA',
#   'items': 20,
#   'practice': 'N81632',
#   'bnf_name': 'Beconase_Aq Nsl Spy 50mcg (200 D) 22g',
#   'nic': 52.6,
#   'act_cost': 48.93,
#   'quantity': 20},
#  {'bnf_code': '1202010M0AAACAC',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#   'nic': 44.04,
#   'act_cost': 40.8,
#   'quantity': 4},
#  {'bnf_code': '1202010M0BBABAB',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Flixonase_Aq Nasule Dps 400mcg Ud',
#   'nic': 25.98,
#   'act_cost': 24.08,
#   'quantity': 56},
#  {'bnf_code': '1202010M0BBACAC',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Flixonase_Aq Nsl Spy 50mcg (150 D)',
#   'nic': 44.04,
#   'act_cost': 40.8,
#   'quantity': 4},
#  {'bnf_code': '1202010U0AAAAAA',
#   'items': 12,
#   'practice': 'N81632',
#   'bnf_name': 'Mometasone Fur_Aq N/Spy 50mcg (140 D)',
#   'nic': 25.44,
#   'act_cost': 23.71,
#   'quantity': 12},
#  {'bnf_code': '1202010U0BBAAAA',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Nasonex_Aq N/Spy 50mcg (140 D)',
#   'nic': 15.36,
#   'act_cost': 14.24,
#   'quantity': 2},
#  {'bnf_code': '1202010W0AAAAAA',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Fluticasone Fur_Nsl Spy 27.5mcg (120D)',
#   'nic': 19.32,
#   'act_cost': 17.92,
#   'quantity': 3},
#  {'bnf_code': '1202010W0BBAAAA',
#   'items': 11,
#   'practice': 'N81632',
#   'bnf_name': 'Avamys_Nsl Spy 27.5mcg (120D)',
#   'nic': 70.84,
#   'act_cost': 65.72,
#   'quantity': 11},
#  {'bnf_code': '1202010Y0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dymista_Nsl Spy 50mcg/137mcg (120 D)',
#   'nic': 14.8,
#   'act_cost': 13.71,
#   'quantity': 1},
#  {'bnf_code': '1202020I0AAABAB',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Ipratrop Brom_Aq Nsl Spy 21mcg (180D)CFF',
#   'nic': 52.32,
#   'act_cost': 48.5,
#   'quantity': 8},
#  {'bnf_code': '1202020L0BJABAD',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Saline Steripoule_Inh Soln 0.9% 2.5ml Ud',
#   'nic': 13.5,
#   'act_cost': 12.51,
#   'quantity': 20},
#  {'bnf_code': '1202030S0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Chlorhex HCl/Neomycin Sulf_Crm 0.1/0.5%',
#   'nic': 2.24,
#   'act_cost': 2.09,
#   'quantity': 15},
#  {'bnf_code': '1202030S0BBAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Naseptin_Crm',
#   'nic': 2.24,
#   'act_cost': 2.09,
#   'quantity': 15},
#  {'bnf_code': '1203010E0AAABAB',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'Benzydamine HCl_Spy 0.15% 30ml S/F',
#   'nic': 28.7,
#   'act_cost': 26.66,
#   'quantity': 7},
#  {'bnf_code': '1203010E0BBABAB',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Difflam_P/Spy 0.15% 30ml',
#   'nic': 4.24,
#   'act_cost': 3.94,
#   'quantity': 1},
#  {'bnf_code': '1203010M0AAAAAA',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hydrocort_Mucoadh Buccal Tab 2.5mg S/F',
#   'nic': 6.69,
#   'act_cost': 6.21,
#   'quantity': 20},
#  {'bnf_code': '1302010U0AAAFAF',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Urea_Crm 10%',
#   'nic': 19.55,
#   'act_cost': 18.14,
#   'quantity': 300},
#  {'bnf_code': '1302010U0BJAAAN',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'E45_Itch Relief Crm',
#   'nic': 3.74,
#   'act_cost': 3.47,
#   'quantity': 100},
#  {'bnf_code': '130201000AAA6A6',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'White Soft Paraf/Liq Paraf_(S) 50%/50%',
#   'nic': 9.14,
#   'act_cost': 8.48,
#   'quantity': 1000},
# ...
#   'quantity': 4},
#  {'bnf_code': '20090000935',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'CliniFast 3.5cm x 1m (Red) Stkntte Elasc',
#   'nic': 0.56,
#   'act_cost': 0.53,
#   'quantity': 1},
#  {'bnf_code': '20090000941',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'CliniFast 7.5cm x 5m (Blue) Stkntte Elas',
#   'nic': 18.7,
#   'act_cost': 17.36,
#   'quantity': 5},
#  {'bnf_code': '20090000947',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'CliniFast 10.75cm x 5m (Yellow) Stkntte',
#   'nic': 48.32,
#   'act_cost': 44.79,
#   'quantity': 8},
#  {'bnf_code': '20100000532',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Micropore 2.5cm x 5m Surg Adh Tape Perm',
#   'nic': 0.92,
#   'act_cost': 0.86,
#   'quantity': 1},
#  {'bnf_code': '20100000596',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Hypafix 5cm x 5m Surg Adh Tape Perm Non-',
#   'nic': 2.92,
#   'act_cost': 2.72,
#   'quantity': 2},
#  {'bnf_code': '21010230115',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Aerochamber Plus',
#   'nic': 38.88,
#   'act_cost': 36.09,
#   'quantity': 8},
#  {'bnf_code': '21010230116',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Aerochamber Plus + Adult/Child/Infant Ma',
#   'nic': 40.55,
#   'act_cost': 37.6,
#   'quantity': 5},
#  {'bnf_code': '21010900431',
#   'items': 10,
#   'practice': 'N81632',
#   'bnf_name': 'Sharpsguard 1L',
#   'nic': 8.5,
#   'act_cost': 8.0,
#   'quantity': 10},
#  {'bnf_code': '21010900432',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'Sharpsafe 1L',
#   'nic': 5.95,
#   'act_cost': 5.6,
#   'quantity': 7},
#  {'bnf_code': '21010900445',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'U100 Syrg Sle Use 0.5ml + 8mm Needle-Ste',
#   'nic': 28.8,
#   'act_cost': 26.69,
#   'quantity': 200},
#  {'bnf_code': '21010900556',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Softclix Lancets 0.4mm/28 Gauge',
#   'nic': 7.93,
#   'act_cost': 7.35,
#   'quantity': 200},
#  {'bnf_code': '21010900559',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Omnican Lance Soft 0.3mm/30 Gauge',
#   'nic': 5.45,
#   'act_cost': 5.06,
#   'quantity': 200},
#  {'bnf_code': '21010900560',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'BD Micro-Fine + Lancets 0.3mm/30 Gauge',
#   'nic': 12.26,
#   'act_cost': 11.38,
#   'quantity': 400},
#  {'bnf_code': '21010900588',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'NovoPen Echo Blue Pen 3ml 0.5u (0.5-30u)',
#   'nic': 26.86,
#   'act_cost': 24.88,
#   'quantity': 1},
#  {'bnf_code': '21010900601',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'BD Microfine+ Needles Pen Inj Screw On 8',
#   'nic': 7.9,
#   'act_cost': 7.33,
#   'quantity': 100},
#  {'bnf_code': '21010900606',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'BD AutoShield Duo Needles Pen Inj Screw',
#   'nic': 30.08,
#   'act_cost': 27.86,
#   'quantity': 100},
#  {'bnf_code': '21010900607',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'BD Viva Needles Pen Inj Screw On 4mm/32',
#   'nic': 10.72,
#   'act_cost': 9.94,
#   'quantity': 180},
#  {'bnf_code': '21010900620',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Microlet Lancets 0.5mm/28 Gauge',
#   'nic': 7.44,
#   'act_cost': 6.9,
#   'quantity': 200},
#  {'bnf_code': '21010900631',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'FreeStyle Lancets 0.5mm/28 Gauge',
#   'nic': 7.44,
#   'act_cost': 6.9,
#   'quantity': 200},
#  {'bnf_code': '21010900686',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Multiclix Lancets 0.3mm/30 Gauge',
#   'nic': 9.93,
#   'act_cost': 9.21,
#   'quantity': 204},
#  {'bnf_code': '21010900687',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'FastClix Lancets 0.3mm/30 Gauge',
#   'nic': 41.3,
#   'act_cost': 38.32,
#   'quantity': 1428},
#  {'bnf_code': '21010900689',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRx Lancets 0.31mm/30 Gauge',
#   'nic': 5.5,
#   'act_cost': 5.1,
#   'quantity': 200},
#  {'bnf_code': '21010900700',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'CarePoint Needles Pen Inj Screw On 6mm',
#   'nic': 19.9,
#   'act_cost': 18.43,
#   'quantity': 200},
#  {'bnf_code': '21010900720',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Unistik 3 Comfort Lancets 1.8mm/28 Gauge',
#   'nic': 44.12,
#   'act_cost': 40.9,
#   'quantity': 700},
#  {'bnf_code': '21010900751',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Omnican Fine Needles Pen Inj Screw On 6m',
#   'nic': 17.85,
#   'act_cost': 16.55,
#   'quantity': 300},
#  {'bnf_code': '21010900752',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Omnican Fine Needles Pen Inj Screw On 8m',
#   'nic': 5.95,
#   'act_cost': 5.52,
#   'quantity': 100},
#  {'bnf_code': '21010900802',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRX FinePoint Needles Pen Inj Screw',
#   'nic': 41.65,
#   'act_cost': 38.63,
#   'quantity': 700},
#  {'bnf_code': '21010900803',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRX FinePoint Needles Pen Inj Screw',
#   'nic': 23.8,
#   'act_cost': 22.06,
#   'quantity': 400},
#  {'bnf_code': '21010900804',
#   'items': 11,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRX FinePoint Needles Pen Inj Screw',
#   'nic': 71.4,
#   'act_cost': 66.23,
#   'quantity': 1200},
#  {'bnf_code': '21010900805',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'GlucoRX FinePoint Needles Pen Inj Screw',
#   'nic': 11.9,
#   'act_cost': 11.04,
#   'quantity': 200},
#  {'bnf_code': '21012500101',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Care Olive Oil Ear Dps Ear Wax Softening',
#   'nic': 4.26,
#   'act_cost': 3.98,
#   'quantity': 3},
#  {'bnf_code': '21012500106',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Alissa Olive Oil Ear Dps Ear Wax Softeni',
#   'nic': 2.84,
#   'act_cost': 2.66,
#   'quantity': 2},
#  {'bnf_code': '21020000309',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'LoFric Non PVC Nelaton Male 8-22 (30-Pac',
#   'nic': 124.2,
#   'act_cost': 114.99,
#   'quantity': 3},
#  {'bnf_code': '21020001155',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hollister VaPro Hydrophilic Male Size 8-',
#   'nic': 104.7,
#   'act_cost': 96.93,
#   'quantity': 2},
#  {'bnf_code': '21020001195',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast SpeediCath Compact Plus Fle 10',
#   'nic': 389.76,
#   'act_cost': 360.82,
#   'quantity': 8},
#  {'bnf_code': '21070510130',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Class 11 Stnd C/Kt B/Knee Stkn Elas Hose',
#   'nic': 22.0,
#   'act_cost': 20.39,
#   'quantity': 4},
#  {'bnf_code': '21070510140',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Class 11 Stnd C/Kt Thigh Stkn Elas Hose',
#   'nic': 24.48,
#   'act_cost': 22.69,
#   'quantity': 4},
#  {'bnf_code': '21140000005',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'K-Y Lubri Jelly',
#   'nic': 2.33,
#   'act_cost': 2.17,
#   'quantity': 82},
#  {'bnf_code': '21210000021',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Glandosane A/Spy 50ml (App)',
#   'nic': 22.72,
#   'act_cost': 21.08,
#   'quantity': 4},
#  {'bnf_code': '21220000100',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Epaderm Oint',
#   'nic': 32.65,
#   'act_cost': 30.29,
#   'quantity': 2500},
#  {'bnf_code': '21220000101',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Epaderm Crm',
#   'nic': 41.7,
#   'act_cost': 38.67,
#   'quantity': 3000},
#  {'bnf_code': '21220000111',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Flexitol Urea Heel Balm',
#   'nic': 7.6,
#   'act_cost': 7.06,
#   'quantity': 150},
#  {'bnf_code': '21220000205',
#   'items': 19,
#   'practice': 'N81632',
#   'bnf_name': 'Hydromol Oint',
#   'nic': 95.79,
#   'act_cost': 88.91,
#   'quantity': 9625},
#  {'bnf_code': '21220000210',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'QV Crm',
#   'nic': 25.74,
#   'act_cost': 23.89,
#   'quantity': 2100},
#  {'bnf_code': '21220000214',
#   'items': 24,
#   'practice': 'N81632',
#   'bnf_name': 'Zerobase Crm (Appl)',
#   'nic': 131.5,
#   'act_cost': 122.04,
#   'quantity': 12500},
#  {'bnf_code': '21220000218',
#   'items': 9,
#   'practice': 'N81632',
#   'bnf_name': 'ZeroAQS Crm',
#   'nic': 29.61,
#   'act_cost': 27.53,
#   'quantity': 4500},
#  {'bnf_code': '21220000235',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'Cetraben Crm 500g',
#   'nic': 23.96,
#   'act_cost': 22.22,
#   'quantity': 4},
#  {'bnf_code': '21220000240',
#   'items': 6,
#   'practice': 'N81632',
#   'bnf_name': 'Cetraben Oint 450g',
#   'nic': 59.29,
#   'act_cost': 54.96,
#   'quantity': 11},
#  {'bnf_code': '21230000101',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'ReplensMD Vag Moist 6D Pack',
#   'nic': 6.06,
#   'act_cost': 5.62,
#   'quantity': 1},
#  {'bnf_code': '21230000110',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Sylk Vag Moist 40g Tube',
#   'nic': 5.16,
#   'act_cost': 4.79,
#   'quantity': 1},
#  {'bnf_code': '21240000120',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Almus Sod Chlor 0.9% Nsl Dps',
#   'nic': 0.99,
#   'act_cost': 0.93,
#   'quantity': 1},
#  {'bnf_code': '21240000160',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Sterimar Isotonic Nsl Spy 50ml',
#   'nic': 7.47,
#   'act_cost': 6.94,
#   'quantity': 3},
#  {'bnf_code': '21290000100',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Kerraped All Purpose Boot Sml/Med/Lge/Ex',
#   'nic': 17.92,
#   'act_cost': 16.6,
#   'quantity': 1},
#  {'bnf_code': '21300000104',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P',
#   'nic': 8.5,
#   'act_cost': 7.88,
#   'quantity': 1},
#  {'bnf_code': '21300000108',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hyabak Sod Hyaluronate Eye Dps 10ml P/F',
#   'nic': 7.99,
#   'act_cost': 7.41,
#   'quantity': 1},
#  {'bnf_code': '21300000110',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Systane Hydroxypropyl Guar Eye Dps 10ml',
#   'nic': 9.32,
#   'act_cost': 8.66,
#   'quantity': 2},
#  {'bnf_code': '21300000111',
#   'items': 8,
#   'practice': 'N81632',
#   'bnf_name': 'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#   'nic': 76.0,
#   'act_cost': 70.46,
#   'quantity': 8},
#  {'bnf_code': '21300000115',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Hydromoor Hypromellose Eye Dps 0.4ml Ud',
#   'nic': 11.5,
#   'act_cost': 10.66,
#   'quantity': 60},
#  {'bnf_code': '21300000123',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Alissa Carmellose 0.5% Eye Dps 10ml',
#   'nic': 7.49,
#   'act_cost': 6.95,
#   'quantity': 1},
#  {'bnf_code': '21300000124',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'Carmize 0.5% Carmellose Eye Dps 10ml',
#   'nic': 52.43,
#   'act_cost': 48.61,
#   'quantity': 7},
#  {'bnf_code': '21300000134',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Optive Fusion Sod Hyaluronate Eye Dps 10',
#   'nic': 14.98,
#   'act_cost': 13.89,
#   'quantity': 2},
#  {'bnf_code': '21300000401',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'nic': 1.93,
#   'act_cost': 1.8,
#   'quantity': 1},
#  {'bnf_code': '21300000702',
#   'items': 13,
#   'practice': 'N81632',
#   'bnf_name': 'Clinitas Carbomer Eye Gel',
#   'nic': 29.8,
#   'act_cost': 27.74,
#   'quantity': 200},
#  {'bnf_code': '21300000711',
#   'items': 4,
#   'practice': 'N81632',
#   'bnf_name': 'Xailin Night Paraf Eye Oint P/F 5g',
#   'nic': 19.92,
#   'act_cost': 18.49,
#   'quantity': 8},
#  {'bnf_code': '21320000101',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Nebusal Sod Chlor 7% Inh Soln 4ml',
#   'nic': 12.6,
#   'act_cost': 11.78,
#   'quantity': 28},
#  {'bnf_code': '23050900500',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'CliniMed_HydroFrame Flng Extender',
#   'nic': 54.08,
#   'act_cost': 50.06,
#   'quantity': 80},
#  {'bnf_code': '23153451503',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Pelican_Release Non-Sting Adh Remover Sa',
#   'nic': 47.79,
#   'act_cost': 44.24,
#   'quantity': 90},
#  {'bnf_code': '23154801502',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'ConvaTec_ConvaTec Niltac Sting Free Medi',
#   'nic': 35.12,
#   'act_cost': 32.51,
#   'quantity': 4},
#  {'bnf_code': '23156001500',
#   'items': 5,
#   'practice': 'N81632',
#   'bnf_name': 'C D Medical_Peel Easy Adh Remover Spy 50',
#   'nic': 78.1,
#   'act_cost': 72.3,
#   'quantity': 11},
#  {'bnf_code': '23351003788',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast_Assura Insp Closed Bag +D/Fltr',
#   'nic': 172.02,
#   'act_cost': 159.25,
#   'quantity': 60},
#  {'bnf_code': '23351003826',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast_SenSura Soft Seal Bag Split Mi',
#   'nic': 198.66,
#   'act_cost': 183.91,
#   'quantity': 60},
#  {'bnf_code': '23351003830',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast_SenSura Mio Orig Midi Clsd Bag',
#   'nic': 350.28,
#   'act_cost': 324.27,
#   'quantity': 120},
#  {'bnf_code': '23351003844',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast_Sensura Mio Maxi Clsd Bag + Fl',
#   'nic': 266.25,
#   'act_cost': 246.48,
#   'quantity': 90},
#  {'bnf_code': '23600706285',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Dansac_Nova 1 Drnbl + E/Fld Ileo Bag Sym',
#   'nic': 88.2,
#   'act_cost': 81.65,
#   'quantity': 30},
#  {'bnf_code': '23601006355',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Coloplast_Sensura Mio Maxi DrnblBag Grey',
#   'nic': 99.63,
#   'act_cost': 92.23,
#   'quantity': 30},
#  {'bnf_code': '23800298001',
#   'items': 7,
#   'practice': 'N81632',
#   'bnf_name': 'Aspen_Sorbaderm No-Sting Barrier Film Sp',
#   'nic': 41.93,
#   'act_cost': 38.91,
#   'quantity': 7},
#  {'bnf_code': '23800298005',
#   'items': 16,
#   'practice': 'N81632',
#   'bnf_name': 'Aspen_Sorbaderm Barrier Crm 92g',
#   'nic': 115.04,
#   'act_cost': 106.69,
#   'quantity': 16},
#  {'bnf_code': '23800298006',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'Aspen_Sorbaderm Barrier Crm 28g',
#   'nic': 7.12,
#   'act_cost': 6.62,
#   'quantity': 2},
#  {'bnf_code': '23800908004',
#   'items': 2,
#   'practice': 'N81632',
#   'bnf_name': 'CliniMed_LBF Ster No Sting Barrier Film',
#   'nic': 101.52,
#   'act_cost': 93.98,
#   'quantity': 4},
#  {'bnf_code': '23803108006',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': '3m Health Care_Cavilon Durable Barrier C',
#   'nic': 8.12,
#   'act_cost': 7.53,
#   'quantity': 1},
#  {'bnf_code': '23803108008',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': '3m Health Care_Cavilon No Sting 1ml Barr',
#   'nic': 25.0,
#   'act_cost': 23.16,
#   'quantity': 5},
#  {'bnf_code': '23803108010',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': '3m Health Care_Cavilon No Sting Barrier',
#   'nic': 17.94,
#   'act_cost': 16.64,
#   'quantity': 3},
#  {'bnf_code': '23804108012',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Salts_Peri-Prep Sens No-Sting Prote Film',
#   'nic': 31.82,
#   'act_cost': 29.46,
#   'quantity': 60},
#  {'bnf_code': '23806008001',
#   'items': 3,
#   'practice': 'N81632',
#   'bnf_name': 'C D Medical_Clinifilm Wipes',
#   'nic': 97.5,
#   'act_cost': 90.26,
#   'quantity': 150},
#  {'bnf_code': '23944809486',
#   'items': 1,
#   'practice': 'N81632',
#   'bnf_name': 'Convatec_Combihesive Natura Flx Flng 38m',
#   'nic': 49.92,
#   'act_cost': 46.21,
#   'quantity': 15},
#  {'bnf_code': '0103010T0AAAAAA',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Ranitidine HCl_Tab 150mg',
#   'nic': 1.24,
#   'act_cost': 1.16,
#   'quantity': 60},
#  {'bnf_code': '0103050L0AAAAAA',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#   'nic': 1.11,
#   'act_cost': 1.04,
#   'quantity': 28},
#  {'bnf_code': '0103050P0AABDBD',
#   'items': 4,
#   'practice': 'Y02045',
#   'bnf_name': 'Omeprazole_Tab E/C 20mg',
#   'nic': 12.04,
#   'act_cost': 11.6,
#   'quantity': 56},
#  {'bnf_code': '0301011R0BEAIAP',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Ventolin_Evohaler 100mcg (200 D)',
#   'nic': 1.5,
#   'act_cost': 1.4,
#   'quantity': 1},
#  {'bnf_code': '0301020Q0AAABAB',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg',
#   'nic': 33.5,
#   'act_cost': 31.03,
#   'quantity': 30},
#  {'bnf_code': '0302000K0AAAUAU',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 400/12(60D',
#   'nic': 38.0,
#   'act_cost': 35.19,
#   'quantity': 1},
#  {'bnf_code': '0303020G0AAABAB',
#   'items': 1,
#   'practice': 'Y02045',
#   'bnf_name': 'Montelukast_Tab 10mg',
#   'nic': 5.18,
#   'act_cost': 4.91,
#   'quantity': 90}]

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:4]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'},
#  {'code': 'A81003',
#   'name': 'VICTORIA MEDICAL PRACTICE',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'VICTORIA ROAD',
#   'borough': 'HARTLEPOOL',
#   'village': 'CLEVELAND',
#   'post_code': 'TS26 8DB'},
#  {'code': 'A81004',
#   'name': 'WOODLANDS ROAD SURGERY',
#   'addr_1': '6 WOODLANDS ROAD',
#   'addr_2': None,
#   'borough': 'MIDDLESBROUGH',
#   'village': 'CLEVELAND',
#   'post_code': 'TS1 3BE'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
def describe(key):

    total = 0
    avg = 0
    s = 0
    q25 = 0
    med = 0
    q75 = 0
    median=[]
    for i in range(len(scripts)):
        median.append(scripts[i][key])
        total+=scripts[i][key]
    avg=total/len(scripts)
    for i in range(len(scripts)):
        s=s+(scripts[i][key]-avg)**2
    s=(s/len(scripts))**(1/2)
    median.sort()
    if len(median)/2==0:
        med=(median[(len(median)/2)-1]+median[(len(median)/2)])/2
        
    else:
        med=median[(len(median)//2)]
        q25=median[((len(median)//2)//2)+1]
        q75=median[(len(median)//2)+(len(median)//4)+1]
    
    return (total, avg, s, q25, med, q75)
print(describe('items'))
# Out:
# (4410054, 11.522744731217633, 33.11216633980368, 1, 3, 8)

# %%
summary = [('items', describe('items')),
           ('quantity', describe('quantity')),
           ('nic', describe('nic')),
           ('act_cost', describe('act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
bnf_names = []
for i in range(len(scripts)):
    if scripts[i]['bnf_name'] not in bnf_names:
        bnf_names.append(scripts[i]['bnf_name'])
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
for script in scripts:
    key=script['bnf_name']
    groups[key].append(script)
    key=[]
#print(groups)

# %%
jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
max_item = [("", 0)]
for key in groups:
    temp=0
    for i in range(len(groups[key])):
        temp+=groups[key][i]['items']
        
    item=[(key,temp)]
    #print(item)
    if temp>max_item[0][1]:
        max_item=item
        
#print(max_item)

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name',)` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
def group_by_field(data,fields):
    names={tuple(dict_[field] for field in fields)
           for dict_ in data}
    groups= {name: [] for name in names}
    for dict_ in data:
        name = tuple(dict_[field] for field in fields)
        groups[name].append(dict_)
    return groups

# %%
most_groups_by_bnf=[]
groups = group_by_field(scripts, ('bnf_name',))
test_max_item = [('',0)]
for key in groups:
    temp=0
    for i in range(len(groups[key])):
        temp+=groups[key][i]['items']
        
    item=[(key,temp)]
    most_groups_by_bnf.append((key,temp))
    #print(item)
    if temp>test_max_item[0][1]:
        test_max_item=item
print(test_max_item)
most_groups_by_bnf.sort()
assert test_max_item == max_item
# Out:
# [(('Omeprazole_Cap E/C 20mg',), 113826)]

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    if practice['code'] in practice_postal:
        if practice_postal[practice['code']]>practice['post_code']:
            practice_postal[practice['code']] = practice['post_code']
            print(practice_postal[practice['code']])
    else:
        practice_postal[practice['code']] = practice['post_code']
        
print(len(practice_postal))
# Out:
# MK45 1DW
# L24 2SP
# S64 5UP
# HD2 1GQ
# TR1 2JA
# TR1 2JA
# HD2 1GQ
# HU1 3SA
# LS17 5DT
# LS17 5DT
# LN2 2JP
# CM3 4EY
# GU17 0DB
# PO7 7AH
# RG28 7AE
# BS10 6SP
# BS10 6SP
# EX20 3JT
# ST19 9BQ
# HU3 4AE
# S1 2PJ
# FY4 4EW
# OL6 9RW
# DN34 4GB
# N19 5BZ
# PR5 6JD
# PO1 2GJ
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# GU9 9QL
# NE12 8EW
# LA11 7DJ
# HU13 0RG
# PL5 1PL
# M7 4NX
# WA10 2BD
# WR1 2AE
# HU17 0HB
# YO24 4HD
# YO24 4HD
# NR31 6QB
# NW9 9AD
# TQ3 2EZ
# BB18 6QT
# BB1 4LA
# B6 5RQ
# WA1 4LS
# SE18 6PZ
# OX3 7JX
# LE11 2TZ
# DY10 1PE
# RG40 1XJ
# DN32 0QE
# WA3 2AP
# DN32 7DJ
# SS4 1RB
# M11 3BB
# LU7 1LB
# RM18 8SD
# TN28 8ER
# CT1 1WL
# PR1 6LL
# WA1 1UQ
# DL3 6HX
# ME7 4PN
# TW3 3EL
# LA14 3HY
# TS25 1QU
# CA1 1DG
# CA1 1DG
# SG1 3QA
# RM14 2YN
# SW11 1JD
# CV37 6HJ
# CV4 9PL
# KT6 6EZ
# KT2 7AZ
# BS16 1EQ
# NE12 8EU
# L35 5DR
# BN11 2AA
# LE11 5DX
# L20 3BG
# CA17 4AY
# BR6 0DP
# B20 2ES
# LS11 5LQ
# TN23 1LQ
# TW1 4HF
# SR6 0AB
# NE38 7NQ
# NE38 7NQ
# L31 0DJ
# IP1 1HE
# E8 3SG
# BH10 4BX
# SO15 3UA
# PO3 5AF
# B77 2ED
# WA2 7LY
# L36 0UB
# DN17 1BS
# BB1 2FD
# BB1 2FD
# BB1 2FD
# B49 6QR
# BB1 2FD
# CM1 7ET
# NG17 1ES
# LS10 2AY
# BL3 6PY
# BB1 2FD
# NR32 1DE
# BB11 2DL
# DH1 2QW
# NR4 6NE
# SE1 6JP
# SE1 6JP
# NE29 6XP
# AL2 1ES
# CV11 5HX
# GL5 2JG
# RM16 2AP
# SE24 9QP
# BH14 0DJ
# SO16 4XE
# BS48 2XX
# EX16 6NJ
# TQ2 6HW
# GL20 5GJ
# GL20 5GJ
# WS13 7HT
# WV1 4PW
# TF3 2JZ
# ST16 2ST
# SW5 0PT
# L20 5DQ
# LU4 0LA
# EN5 2ED
# OL12 0NB
# M24 2EL
# OL10 1LR
# CB22 3HU
# SW1X 0ET
# CV2 1AB
# L7 6HD
# LA1 1PN
# M34 2AJ
# NR2 3TU
# SE18 2AE
# TS24 8QG
# GU1 1LJ
# GU1 1LJ
# L40 4LA
# NE10 9QG
# LE16 7BN
# BN3 3AT
# BN3 3AT
# BS17 4AA
# ST3 1EQ
# LA1 1PN
# PR1 6LL
# SO14 0LX
# LS10 4UZ
# L18 8BU
# SM6 0DX
# NE27 0BY
# BS1 5SZ
# SO14 0LX
# 10843

# %%
practice_postal_=group_by_field(practices,('code',))
print(len(practice_postal_))
# Out:
# 10843

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts
for i in range(len(joined)):
    joined[i]['post_code']=practice_postal[joined[i]['practice']]
    #script['post_code'] = practice_postal[script['practice']]
joined[9900]
# Out:
# {'bnf_code': '21010900703',
#  'items': 1,
#  'practice': 'N81010',
#  'bnf_name': 'CarePoint Needles Pen Inj Screw On 4mm',
#  'nic': 9.95,
#  'act_cost': 9.22,
#  'quantity': 100,
#  'post_code': 'CW5 5NX'}

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %%
# !cd /home/jovyan/
# !pwd
# Out:
# /home/jovyan/datacourse/data-wrangling/miniprojects

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
#items_by_post = ...
items_by_post=group_by_field(joined,('post_code',))

# %%
postal_total = []

for postitems in items_by_post:
    temp=0
    for i in range(len(items_by_post[postitems])):
        temp+=items_by_post[postitems][i]['items']
    
    postal_total.append((postitems[0],temp))
postal_total.sort()
print(postal_total[:10])
postal_totals=postal_total[:100]
grader.score.pw__postal_totals(postal_totals)
# Out:
# [('B11 4BW', 20673), ('B18 7AL', 19001), ('B21 9RY', 29103), ('B23 6DJ', 24859), ('B70 7AW', 36531), ('BB11 2DL', 34356), ('BB2 1AX', 28254), ('BB3 1PY', 54514), ('BB4 5SL', 29388), ('BB7 2JG', 44585)]
# ==================
# Your score: 1.000
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.
#
# There are several approaches to solve this problem but we will guide you through one of them. Feel free to solve it your own way if it is easier for you to understand and implement. If your kernel keeps on dying, it's probably an indication that you are running out of memory. Consider deleting objects you don't need anymore using the `del` statement and shutdown any other running notebooks. For example:
# ```Python
# del some_object_not_needed
# ```

# %% [markdown]
# The first step is to calculate the total items for each `'post_code'` and `'bnf_name'`. Let's call that result `total_items_by_post_bnf`. Consider what is the best data structure(s) to represent `total_items_by_post_bnf`. It should have 141196 `('post_code', 'bnf_name')` groups.

# %%
total_items_by_post_bnf = {}
for key, group in list(group_by_field(joined, ('post_code', 'bnf_name')).items()):
    items_total=sum(d['items'] for d in group)
    total_items_by_post_bnf[key]=items_total 
assert len(total_items_by_post_bnf) == 141196
#print(total_items_by_post_bnf)

# %%
total_items = []
for (post_code, bnf_name), total in list(total_items_by_post_bnf.items()):
        new_dict = {'post_code' : post_code,
                    'bnf_name' : bnf_name,
                    'total' : total}
        total_items.append(new_dict)

# %% [markdown]
# Next, let's take `total_items_by_post_bnf` and group it by `'post_code'`. In other words, we want a  data structure that maps a `'post_code'` to a list of all records that belong to that `'post_code'`. There should be 118 groups.

# %%
total_items_by_post=group_by_field(total_items, ('post_code',))
assert len(total_items_by_post) == 118
print(total_items_by_post.keys())
# Out:
# dict_keys([('BB3 1PY',), ('L36 7XY',), ('BL3 5HP',), ('SE1 6JP',), ('TS1 2NX',), ('NW10 8RY',), ('WN7 2PE',), ('SS13 3HQ',), ('M30 0NU',), ('WS10 8SY',), ('BB8 0JZ',), ('CW1 3AW',), ('DN34 4GB',), ('TS23 2DG',), ('CH1 4DS',), ('RM3 9SU',), ('N9 7HD',), ('KT6 6EZ',), ('WN2 5NG',), ('M26 2SP',), ('M11 4EJ',), ('NE38 7NQ',), ('TS24 7PW',), ('CH65 6TG',), ('WS3 3JP',), ('W10 6DZ',), ('S63 9EH',), ('OL4 1YN',), ('DA1 2HA',), ('TN24 0GP',), ('NE10 9QG',), ('FY7 8GU',), ('SR5 2LT',), ('NE24 1DX',), ('SS8 0JA',), ('TS10 4NW',), ('S65 1DA',), ('ST3 6AB',), ('FY4 1TJ',), ('GL1 3PX',), ('HA3 7LT',), ('CV1 4FS',), ('FY2 0JG',), ('WD18 0JP',), ('WN3 5HL',), ('DA11 8BZ',), ('SE15 5LJ',), ('BB9 7SR',), ('YO16 4LZ',), ('NE37 2PU',), ('S74 9AF',), ('SS0 7AF',), ('BB2 1AX',), ('BB7 2JG',), ('BL1 8TU',), ('B18 7AL',), ('FY5 2TZ',), ('GU9 9QS',), ('LE5 3GH',), ('SK6 1ND',), ('B70 7AW',), ('WA7 1AB',), ('GL50 4DP',), ('L31 0DJ',), ('NN16 8DN',), ('NG7 3GW',), ('OL11 1DN',), ('SM6 0HY',), ('PL7 1AD',), ('HA0 4UZ',), ('B21 9RY',), ('BB4 5SL',), ('TS17 0EE',), ('NG7 5HY',), ('DN22 7XF',), ('WV13 2DR',), ('WA10 2DJ',), ('CW5 5NX',), ('CB9 8HF',), ('LN2 2JP',), ('ST1 4PB',), ('LE18 2EW',), ('WN7 1HR',), ('LE10 1DS',), ('BH23 3AF',), ('KT14 6DH',), ('TN34 1BA',), ('ST8 6AG',), ('TW13 4GU',), ('SR4 7XF',), ('L7 6HD',), ('WF13 1HN',), ('B23 6DJ',), ('HG1 5AR',), ('BL9 0SN',), ('WA9 1LN',), ('BH18 8EE',), ('CT11 8AD',), ('OL1 1NL',), ('BB11 2DL',), ('BL9 0NJ',), ('B11 4BW',), ('L5 0QW',), ('TR1 2JA',), ('TS3 6AL',), ('SK11 6JL',), ('TW3 3LN',), ('HU7 4DW',), ('SM3 8EP',), ('TW8 8DS',), ('SS9 5UU',), ('ME8 8AA',), ('BD3 8QH',), ('LA1 1PN',), ('OL9 7AY',), ('M35 0AD',), ('LS9 9EF',), ('CW7 1AT',)])

# %%
items_by_post=group_by_field(joined, ('post_code',))
print(items_by_post.keys())
# Out:
# dict_keys([('BB3 1PY',), ('L36 7XY',), ('BL3 5HP',), ('SE1 6JP',), ('TS1 2NX',), ('NW10 8RY',), ('WN7 2PE',), ('SS13 3HQ',), ('M30 0NU',), ('WS10 8SY',), ('BB8 0JZ',), ('CW1 3AW',), ('DN34 4GB',), ('TS23 2DG',), ('CH1 4DS',), ('N9 7HD',), ('RM3 9SU',), ('KT6 6EZ',), ('WN2 5NG',), ('M26 2SP',), ('M11 4EJ',), ('NE38 7NQ',), ('TS24 7PW',), ('CH65 6TG',), ('WS3 3JP',), ('W10 6DZ',), ('S63 9EH',), ('OL4 1YN',), ('TN24 0GP',), ('DA1 2HA',), ('NE10 9QG',), ('FY7 8GU',), ('SR5 2LT',), ('NE24 1DX',), ('SS8 0JA',), ('TS10 4NW',), ('S65 1DA',), ('ST3 6AB',), ('FY4 1TJ',), ('GL1 3PX',), ('HA3 7LT',), ('CV1 4FS',), ('FY2 0JG',), ('WD18 0JP',), ('WN3 5HL',), ('SE15 5LJ',), ('DA11 8BZ',), ('BB9 7SR',), ('NE37 2PU',), ('YO16 4LZ',), ('S74 9AF',), ('SS0 7AF',), ('BB2 1AX',), ('BB7 2JG',), ('BL1 8TU',), ('B18 7AL',), ('FY5 2TZ',), ('GU9 9QS',), ('LE5 3GH',), ('SK6 1ND',), ('B70 7AW',), ('WA7 1AB',), ('GL50 4DP',), ('L31 0DJ',), ('NN16 8DN',), ('NG7 3GW',), ('OL11 1DN',), ('SM6 0HY',), ('PL7 1AD',), ('HA0 4UZ',), ('B21 9RY',), ('BB4 5SL',), ('TS17 0EE',), ('NG7 5HY',), ('DN22 7XF',), ('WV13 2DR',), ('WA10 2DJ',), ('CW5 5NX',), ('CB9 8HF',), ('LN2 2JP',), ('ST1 4PB',), ('LE18 2EW',), ('WN7 1HR',), ('LE10 1DS',), ('KT14 6DH',), ('BH23 3AF',), ('TN34 1BA',), ('ST8 6AG',), ('TW13 4GU',), ('SR4 7XF',), ('L7 6HD',), ('WF13 1HN',), ('B23 6DJ',), ('HG1 5AR',), ('BL9 0SN',), ('WA9 1LN',), ('BH18 8EE',), ('CT11 8AD',), ('OL1 1NL',), ('BB11 2DL',), ('BL9 0NJ',), ('B11 4BW',), ('L5 0QW',), ('TS3 6AL',), ('TR1 2JA',), ('SK11 6JL',), ('TW3 3LN',), ('HU7 4DW',), ('SM3 8EP',), ('TW8 8DS',), ('SS9 5UU',), ('ME8 8AA',), ('BD3 8QH',), ('LA1 1PN',), ('OL9 7AY',), ('M35 0AD',), ('LS9 9EF',), ('CW7 1AT',)])

# %%
total_items = []
for (post_code, bnf_name), total in list(total_items_by_post_bnf.items()):
        new_dict = {'post_code' : post_code,
                    'bnf_name' : bnf_name,
                    'total' : total}
        total_items.append(new_dict)

# %%
from operator import itemgetter
get_total = itemgetter('total')
max_item_by_post = []
groups = list(total_items_by_post.values())
for group in groups:
    #print(max_total)
    max_total = sorted(group, key=itemgetter('total'), reverse=True)[0]
    max_item_by_post.append(max_total)

# %% [markdown]
# Now with `grouped_post_code`, let's iterate over each group and calculate the following fields for each `'post_code'`:
# 1. the sum of total items for all `'bnf_name'`
# 1. the most total items
# 1. the `'bnf_name'` that had the most total items
#
# Once again, consider the best data structure(s) to use to represent the result. It may help to write and use a function when developing your solution.

# %%
max_item_by_post = [sorted(group, key=itemgetter('total'), reverse=True)[0]
                    for group in list(total_items_by_post.values())]
print(max_item_by_post[1])
# Out:
# {'post_code': 'BB2 1AX', 'bnf_name': 'Omeprazole_Cap E/C 20mg', 'total': 1030}

# %%
items_by_region = [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)] * 100
items_by_region
# Out:
# [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247),
#  ('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.0341508247)]

# %% [markdown]
# Now, we are ready to:
# 1. calculate the ratio (the amount dispensed as proportion of total)
# 1. [sort](https://docs.python.org/3/howto/sorting.html) alphabetically by the post code
# 1. format the answer as a list of tuples
# 1. take only the first 100 tuples
# 1. submit to the grader

# %%
item_by_region=[]
items_by_region=[]
for item in max_item_by_post:
    i=0
    numerator= item['total']
    #print(total_items_by_post[(item['post_code'],)][i]['total'])
    denominator=(items_by_post[(item['post_code'],)][i]['items'])
    #denominator=dict(items_by_post[item[key,]]['items'])
    proportion=numerator/denominator
    result=(item['post_code'], item['bnf_name'], proportion)
    item_by_region.append(result)
    i+=1
item_by_region.sort()

for i in range(100):
    items_by_region.append(item_by_region[i])
    
    
items_by_region
# Out:
# [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 100.85714285714286),
#  ('B18 7AL', 'Salbutamol_Inha 100mcg (200 D) CFF', 278.0),
#  ('B21 9RY', 'Metformin HCl_Tab 500mg', 1033.0),
#  ('B23 6DJ', 'Lansoprazole_Cap 30mg (E/C Gran)', 119.8),
#  ('B70 7AW', 'Paracet_Tab 500mg', 975.0),
#  ('BB11 2DL', 'Omeprazole_Cap E/C 20mg', 991.0),
#  ('BB2 1AX', 'Omeprazole_Cap E/C 20mg', 1030.0),
#  ('BB3 1PY', 'Omeprazole_Cap E/C 20mg', 1869.0),
#  ('BB4 5SL', 'Omeprazole_Cap E/C 20mg', 1196.0),
#  ('BB7 2JG', 'Omeprazole_Cap E/C 20mg', 438.0),
#  ('BB8 0JZ', 'Atorvastatin_Tab 20mg', 1227.0),
#  ('BB9 7SR', 'Omeprazole_Cap E/C 20mg', 182.2),
#  ('BD3 8QH', 'Atorvastatin_Tab 40mg', 719.0),
#  ('BH18 8EE', 'Omeprazole_Cap E/C 20mg', 571.5),
#  ('BH23 3AF', 'Omeprazole_Cap E/C 20mg', 1215.0),
#  ('BL1 8TU', 'Omeprazole_Cap E/C 20mg', 404.5),
#  ('BL3 5HP', 'Omeprazole_Cap E/C 20mg', 456.0),
#  ('BL9 0NJ', 'Omeprazole_Cap E/C 20mg', 359.3333333333333),
#  ('BL9 0SN', 'Omeprazole_Cap E/C 20mg', 1149.0),
#  ('CB9 8HF', 'Omeprazole_Cap E/C 20mg', 306.8333333333333),
#  ('CH1 4DS', 'Lansoprazole_Cap 30mg (E/C Gran)', 235.5),
#  ('CH65 6TG', 'Lansoprazole_Cap 30mg (E/C Gran)', 344.0),
#  ('CT11 8AD', 'Omeprazole_Cap E/C 20mg', 36.275862068965516),
#  ('CV1 4FS', 'Omeprazole_Cap E/C 20mg', 370.6666666666667),
#  ('CW1 3AW', 'Omeprazole_Cap E/C 20mg', 2364.0),
#  ('CW5 5NX', 'Omeprazole_Cap E/C 20mg', 354.75),
#  ('CW7 1AT', 'Omeprazole_Cap E/C 20mg', 61.2962962962963),
#  ('DA1 2HA', 'Omeprazole_Cap E/C 20mg', 547.0),
#  ('DA11 8BZ', 'Amoxicillin_Cap 500mg', 103.6),
#  ('DN22 7XF', 'Simvastatin_Tab 40mg', 171.4),
#  ('DN34 4GB', 'Omeprazole_Cap E/C 20mg', 467.5),
#  ('FY2 0JG', 'Omeprazole_Cap E/C 20mg', 2623.0),
#  ('FY4 1TJ', 'Omeprazole_Cap E/C 20mg', 1419.0),
#  ('FY5 2TZ', 'Omeprazole_Cap E/C 20mg', 1663.0),
#  ('FY7 8GU', 'Omeprazole_Cap E/C 20mg', 196.5),
#  ('GL1 3PX', 'Omeprazole_Cap E/C 20mg', 521.0),
#  ('GL50 4DP', 'Omeprazole_Cap E/C 20mg', 924.0),
#  ('GU9 9QS', 'Omeprazole_Cap E/C 20mg', 306.3333333333333),
#  ('HA0 4UZ', 'Metformin HCl_Tab 500mg', 674.0),
#  ('HA3 7LT', 'Omeprazole_Cap E/C 20mg', 851.0),
#  ('HG1 5AR', 'Omeprazole_Cap E/C 20mg', 981.0),
#  ('HU7 4DW', 'Salbutamol_Inha 100mcg (200 D) CFF', 217.66666666666666),
#  ('KT14 6DH', 'Amlodipine_Tab 5mg', 176.66666666666666),
#  ('KT6 6EZ', 'Omeprazole_Cap E/C 20mg', 1152.0),
#  ('L31 0DJ', 'Omeprazole_Cap E/C 20mg', 124.625),
#  ('L36 7XY', 'Salbutamol_Inha 100mcg (200 D) CFF', 233.33333333333334),
#  ('L5 0QW', 'Omeprazole_Cap E/C 20mg', 55.666666666666664),
#  ('L7 6HD', 'Salbutamol_Inha 100mcg (200 D) CFF', 1144.0),
#  ('LA1 1PN', 'Omeprazole_Cap E/C 20mg', 567.0),
#  ('LE10 1DS', 'Aspirin Disper_Tab 75mg', 1091.0),
#  ('LE18 2EW', 'Lansoprazole_Cap 15mg (E/C Gran)', 493.0),
#  ('LE5 3GH', 'Metformin HCl_Tab 500mg', 508.5),
#  ('LN2 2JP', 'Omeprazole_Cap E/C 20mg', 557.0),
#  ('LS9 9EF', 'Lansoprazole_Cap 30mg (E/C Gran)', 139.0909090909091),
#  ('M11 4EJ', 'Omeprazole_Cap E/C 20mg', 247.66666666666666),
#  ('M26 2SP', 'Omeprazole_Cap E/C 20mg', 1541.0),
#  ('M30 0NU', 'Omeprazole_Cap E/C 20mg', 979.0),
#  ('M35 0AD', 'Omeprazole_Cap E/C 20mg', 232.2),
#  ('ME8 8AA', 'Omeprazole_Cap E/C 20mg', 294.0),
#  ('N9 7HD', 'Lansoprazole_Cap 30mg (E/C Gran)', 36.68181818181818),
#  ('NE10 9QG', 'Paracet_Tab 500mg', 883.5),
#  ('NE24 1DX', 'Paracet_Tab 500mg', 269.8333333333333),
#  ('NE37 2PU', 'Paracet_Tab 500mg', 1597.0),
#  ('NE38 7NQ', 'Paracet_Tab 500mg', 1644.0),
#  ('NG7 3GW', 'Paracet_Tab 500mg', 79.0),
#  ('NG7 5HY', 'Paracet_Tab 500mg', 312.5),
#  ('NN16 8DN', 'Omeprazole_Cap E/C 20mg', 1801.0),
#  ('NW10 8RY', 'Metformin HCl_Tab 500mg', 666.0),
#  ('OL1 1NL', 'Omeprazole_Cap E/C 20mg', 1372.0),
#  ('OL11 1DN', 'Omeprazole_Cap E/C 20mg', 347.0),
#  ('OL4 1YN', 'Omeprazole_Cap E/C 20mg', 738.0),
#  ('OL9 7AY', 'Omeprazole_Cap E/C 20mg', 17.12727272727273),
#  ('PL7 1AD', 'Omeprazole_Cap E/C 20mg', 1254.5),
#  ('RM3 9SU', 'Salbutamol_Inha 100mcg (200 D) CFF', 233.66666666666666),
#  ('S63 9EH', 'Salbutamol_Inha 100mcg (200 D) CFF', 130.625),
#  ('S65 1DA', 'Influenza_Vac Inact 0.5ml Pfs', 340.8),
#  ('S74 9AF', 'Omeprazole_Cap E/C 20mg', 331.3333333333333),
#  ('SE1 6JP', 'Metformin HCl_Tab 500mg', 1051.0),
#  ('SE15 5LJ', 'Metformin HCl_Tab 500mg', 374.0),
#  ('SK11 6JL', 'Omeprazole_Cap E/C 20mg', 1609.5),
#  ('SK6 1ND', 'Lansoprazole_Cap 30mg (E/C Gran)', 540.0),
#  ('SM3 8EP', 'Omeprazole_Cap E/C 20mg', 148.6),
#  ('SM6 0HY', 'Omeprazole_Cap E/C 20mg', 729.5),
#  ('SR4 7XF', 'Paracet_Tab 500mg', 425.5),
#  ('SR5 2LT', 'Paracet_Tab 500mg', 1618.0),
#  ('SS0 7AF', 'Omeprazole_Cap E/C 20mg', 457.0),
#  ('SS13 3HQ', 'Lansoprazole_Cap 30mg (E/C Gran)', 985.0),
#  ('SS8 0JA', 'Omeprazole_Cap E/C 20mg', 411.0),
#  ('SS9 5UU', 'Influvac Sub-Unit_Vac 0.5ml Pfs', 662.0),
#  ('ST1 4PB', 'Omeprazole_Cap E/C 20mg', 179.25),
#  ('ST3 6AB', 'Omeprazole_Cap E/C 20mg', 134.55555555555554),
#  ('ST8 6AG', 'Omeprazole_Cap E/C 20mg', 1368.0),
#  ('TN24 0GP', 'Amoxicillin_Cap 500mg', 1440.0),
#  ('TN34 1BA', 'Omeprazole_Cap E/C 20mg', 736.0),
#  ('TR1 2JA', 'Omeprazole_Cap E/C 20mg', 232.625),
#  ('TS1 2NX', 'Paracet_Tab 500mg', 656.0),
#  ('TS10 4NW', 'Paracet_Tab 500mg', 1049.0),
#  ('TS17 0EE', 'Lansoprazole_Cap 30mg (E/C Gran)', 285.5),
#  ('TS23 2DG', 'Paracet_Tab 500mg', 404.0),
#  ('TS24 7PW', 'Paracet_Tab 500mg', 1123.0)]

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score: 0.000
# ==================

# %% [markdown]
# *Copyright &copy; 2021 WorldQuant University. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
